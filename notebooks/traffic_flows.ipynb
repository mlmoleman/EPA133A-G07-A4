# %%
import pandas as pd
from io import StringIO   #in order to pass literal# strings to pandas_read_html this class is necessary.
from bs4 import BeautifulSoup
from urllib.request import urlopen

# %%
# #retrieving traffic flow data for roads in network
# def retrieve_traffic_data(road):
#     """Retrieve html traffic flow data in an automated way"""
#     url = "../data/"+ road+"_traffic.htm"
#     with open(url) as file:
#         soup = BeautifulSoup(file, features="xml") #use BeautifulSoup to parse, use 'xml' because the table in the HTML is an excel table
#     tables = pd.read_html(StringIO(str(soup)), header=[1,2]) #use StringIO to supress future deprication warning. Use header[1,2] to define the multi-index headers to use
#     df = tables[3]
#     return df

# %%
# intersections_network = pd.read_csv("../data/intersections.csv")
# intersections_network
# Out:
#     Unnamed: 0  road  chainage      lrp        lat        lon  gap  \
# 0            0    N1    81.801  LRP083a  23.478944  91.117722  NaN
# 1            1    N1   143.795   LRP147  23.019360  91.369777  NaN
# 2            2    N1    10.885  LRP011a  23.694361  90.537611  NaN
# 3            3    N1     8.000   LRP008  23.702056  90.515722  NaN
# 4            4    N1     0.000     LRPS  23.706028  90.443333  NaN
# 5            5    N2     0.000     LRPS  23.705917  90.521444  NaN
# 6            6    N2    85.098  LRP085b  24.049694  91.107639  NaN
# 7            7    N2    10.196   LRP011  23.777472  90.561667  NaN
# 8            8    N2   115.916   LRP117  24.146639  91.343055  NaN
# 9            9    N2   145.041   LRP146  24.289222  91.503444  NaN
# 10          10    N2   226.493   LRP227  24.871499  91.866250  NaN
# 11          11  N102     0.000     LRPS  23.478972  91.118194  NaN
# 12          12  N104     0.445    LRPSa  23.009278  91.395250  NaN
# ...

# %%
# intersections_roads = list(intersections_network.road.unique())

# %%
# traffic_df_dict = {}
# for road in intersections_roads:
#     df_name = f"traffic_{road}"
#     df = retrieve_traffic_data(road)
#     traffic_df_dict[df_name] = df
# Out:
# C:\Users\nelen\EPA133A-G07-A4\venv\Lib\site-packages\pandas\io\html.py:666: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   soup = BeautifulSoup(udoc, features="html5lib", from_encoding=from_encoding)
# ...

# %%
# for name, df in traffic_df_dict.items():
#     csv_filename = f'../data/{name}.csv'
#     df.to_csv(csv_filename)
#     print(f"DataFrame '{name}' saved to '{csv_filename}'")
# Out:
# DataFrame 'traffic_N1' saved to '../data/traffic_N1.csv'
# DataFrame 'traffic_N2' saved to '../data/traffic_N2.csv'
# DataFrame 'traffic_N102' saved to '../data/traffic_N102.csv'
# DataFrame 'traffic_N104' saved to '../data/traffic_N104.csv'
# DataFrame 'traffic_N105' saved to '../data/traffic_N105.csv'
# DataFrame 'traffic_N8' saved to '../data/traffic_N8.csv'
# DataFrame 'traffic_N204' saved to '../data/traffic_N204.csv'
# DataFrame 'traffic_N207' saved to '../data/traffic_N207.csv'
# DataFrame 'traffic_N208' saved to '../data/traffic_N208.csv'

# %% [markdown]
# # Checking all loaded csv files for correctness

# %%
df_traffic_N1 = pd.read_csv("../data/traffic_N1.csv", header=[0,1])
df_traffic_N2 = pd.read_csv('../data/traffic_N2.csv', header=[0,1])
df_traffic_N102 = pd.read_csv('../data/traffic_N102.csv', header=[0,1])
df_traffic_N104 = pd.read_csv('../data/traffic_N104.csv', header=[0,1])
df_traffic_N105 = pd.read_csv('../data/traffic_N105.csv', header=[0,1])
df_traffic_N8 = pd.read_csv('../data/traffic_N8.csv', header=[0,1])
df_traffic_N204 = pd.read_csv('../data/traffic_N204.csv', header=[0,1])
df_traffic_N207 = pd.read_csv('../data/traffic_N207.csv', header=[0,1])
df_traffic_N208 = pd.read_csv('../data/traffic_N208.csv', header=[0,1])

# %% [markdown]
# # all html tables were correctly scraped

# %%
df_traffic_N1
# Out:
#     Unnamed: 0_level_0            Link no  \
#     Unnamed: 0_level_1 Unnamed: 0_level_1
# 0                    0              N1-1L
# 1                    1              N1-1R
# 2                    2              N1-2L
# 3                    3              N1-2R
# 4                    4              N1-3L
# ..                 ...                ...
# 100                100              N1-65
# 101                101              N1-66
# 102                102              N1-67
# 103                103              N1-68
# 104                104              N1-69
#
#                                                Name Start location         \
#                                  Unnamed: 1_level_1            LRP Offset
# 0          Jatrabari - Int.with Z1101 (Left) (Left)           LRPS      0
# 1         Jatrabari - Int.with Z1101 (Left) (Right)           LRPS      0
# 2     Int.with Z1101 - Signboard (Left) R111 (Left)           LRPS    822
# ...

# %%
df_traffic_N2
# Out:
#    Unnamed: 0_level_0            Link no  \
#    Unnamed: 0_level_1 Unnamed: 0_level_1
# 0                   0               N2-1
# 1                   1               N2-2
# 2                   2               N2-3
# 3                   3               N2-4
# 4                   4               N2-5
# 5                   5               N2-6
# 6                   6               N2-7
# 7                   7               N2-8
# 8                   8               N2-9
# 9                   9              N2-10
# 10                 10              N2-11
# 11                 11              N2-12
# 12                 12              N2-13
# 13                 13              N2-14
# 14                 14              N2-15
# 15                 15              N2-16
# 16                 16              N2-17
# 17                 17              N2-18
# 18                 18              N2-19
# 19                 19              N2-20
# 20                 20              N2-21
# ...

# %%
df_traffic_N8
# Out:
#    Unnamed: 0_level_0            Link no  \
#    Unnamed: 0_level_1 Unnamed: 0_level_1
# 0                   0               N8-1
# 1                   1               N8-2
# 2                   2               N8-3
# 3                   3               N8-4
# 4                   4               N8-5
# 5                   5               N8-6
# 6                   6               N8-7
# 7                   7               N8-8
# 8                   8               N8-9
# 9                   9              N8-10
# 10                 10              N8-11
# 11                 11              N8-12
# 12                 12              N8-13
# 13                 13              N8-14
# 14                 14              N8-15
# 15                 15              N8-16
# 16                 16              N8-17
# 17                 17              N8-18
# 18                 18              N8-19
# 19                 19              N8-20
# 20                 20              N8-21
# ...

# %%
df_traffic_N102
# Out:
#   Unnamed: 0_level_0            Link no  \
#   Unnamed: 0_level_1 Unnamed: 0_level_1
# 0                  0             N102-1
# 1                  1             N102-2
# 2                  2             N102-3
# 3                  3             N102-4
# 4                  4             N102-5
# 5                  5             N102-6
# 6                  6             N102-7
# 7                  7             N102-8
# 8                  8             N102-9
# 9                  9            N102-10
#
#                                                 Name Start location         \
#                                   Unnamed: 1_level_1            LRP Offset
# 0    Mainamati-Kangsanagar (Intersection with Z1219)           LRPS      0
# 1  Kangsanagar (Int with Z1219)-Debidduar (Int wi...         LRP009   1110
# 2  Debiduar (Int with Z1008)- Companiganj (Int wi...         LRP018   2570
# 3  Companiganj (Int with Z1205) - Mirpur (Int wit...         LRP024   1242
# ...

# %%
df_traffic_N104
# Out:
#    Unnamed: 0_level_0            Link no  \
#    Unnamed: 0_level_1 Unnamed: 0_level_1
# 0                   0             N104-1
# 1                   1             N104-2
# 2                   2             N104-3
# 3                   3             N104-4
# 4                   4             N104-5
# 5                   5             N104-6
# 6                   6             N104-7
# 7                   7             N104-8
# 8                   8             N104-9
# 9                   9            N104-10
# 10                 10            N104-11
#
#                                                  Name Start location         \
#                                    Unnamed: 1_level_1            LRP Offset
# 0   Feni (Trank Road)-Feni (Mohipal Chourasta) Int...           LRPS      0
# 1   Feni (Int. with N1)-Feni (Temohoni)Int.with Z1444           LRPS   1878
# 2   Feni (Temohoni)Int.with Z1444-Selonia (Int.wit...         LRP004    270
# ...

# %%
df_traffic_N105
# Out:
#   Unnamed: 0_level_0            Link no  \
#   Unnamed: 0_level_1 Unnamed: 0_level_1
# 0                  0             N105-1
# 1                  1             N105-2
# 2                  2             N105-3
# 3                  3             N105-4
# 4                  4             N105-5
# 5                  5             N105-6
# 6                  6             N105-7
#
#                                                 Name Start location         \
#                                   Unnamed: 1_level_1            LRP Offset
# 0  Madanpur (13th km of N1)-Nayapur, Bostail (Int...           LRPS      0
# 1  Nayapur, Bostail(Int.with R114)-Bhulta (Int.wi...         LRP006    181
# 2                Bhulta (Int.with N2)-Purbachal Road         LRP012    546
# 3          Purbachal Road- Ulukhola (Int.with Z3010)        LRP020d      0
# 4  Ulukhola (Int.with Z3010)-Mirer Bazar (Int.wit...         LRP028    895
# ...

# %%
df_traffic_N204
# Out:
#   Unnamed: 0_level_0            Link no  \
#   Unnamed: 0_level_1 Unnamed: 0_level_1
# 0                  0             N204-1
# 1                  1             N204-2
#
#                                         Name Start location                  \
#                           Unnamed: 1_level_1            LRP Offset Chainage
# 0   Jagadishpur-Chunarughat (Int.with Z2008)           LRPS      0    0.000
# 1  Chunarughat (Int.with Z2008)-Shaisthaganj         LRP022   5439   25.449
#
#   End location                  Length  ... Traffic Data                \
#            LRP Offset Chainage    (Km)  ...          Car Auto Rickshaw
# 0       LRP022   5439   25.449  25.449  ...         92.0        1119.0
# 1         LRPE      0   34.421   8.972  ...         92.0        1119.0
#
#                                                Total                           \
#   Motor Cycle Bi-Cycle Cycle Rickshaw Cart Motorized Non Motorized Total AADT
# ...

# %%
df_traffic_N207
# Out:
#   Unnamed: 0_level_0            Link no  \
#   Unnamed: 0_level_1 Unnamed: 0_level_1
# 0                  0             N207-1
# 1                  1             N207-2
# 2                  2             N207-3
# 3                  3             N207-4
#
#                                                 Name Start location         \
#                                   Unnamed: 1_level_1            LRP Offset
# 0                Mirpur-Natun Bazar (Int.with Z2008)           LRPS      0
# 1  Natun Bazar (Int.with Z2008)-Srimongal (Int.wi...         LRP001   1990
# 2  Srimongal (Int.with Z2003)-Moulvibazar (Int.wi...         LRP024    464
# 3                Moulvibazar (Int.with N208)-Sherpur         LRP043     12
#
#            End location                  Length  ... Traffic Data  \
#   Chainage          LRP Offset Chainage    (Km)  ...          Car
# 0    0.000       LRP001   1990    2.990   2.990  ...        386.0
# 1    2.990       LRP024    464   24.319  21.329  ...        386.0
# ...

# %%
df_traffic_N208
# Out:
#   Unnamed: 0_level_0            Link no  \
#   Unnamed: 0_level_1 Unnamed: 0_level_1
# 0                  0             N208-1
# 1                  1             N208-2
# 2                  2             N208-3
# 3                  3             N208-4
# 4                  4             N208-5
#
#                                                 Name Start location         \
#                                   Unnamed: 1_level_1            LRP Offset
# 0                         Moulvibazar-Int.with Z2002           LRPS      0
# 1            Int.with Z2002-Rajnagar (Int.with R281)           LRPS   3190
# 2  Rajnagar(Int.with R281)-Daudabad (Int.with Z2832)         LRP012   1661
# 3  Daudabad (Int.with Z2832)-Royal City Chottor(i...         LRP052    385
# 4      Royal City Chottor(int.with N210)-Int.with N2         LRP054    677
#
#            End location                  Length  ... Traffic Data  \
#   Chainage          LRP Offset Chainage    (Km)  ...          Car
# ...

# %% [markdown]
# # combining all dataframes into one large dataframe

# %%
#make one large dataframe of all roads's traffic flows
df_traffic = pd.concat([df_traffic_N1,
df_traffic_N2,
df_traffic_N102,
df_traffic_N104,
df_traffic_N105,
df_traffic_N8,
df_traffic_N204,
df_traffic_N207,
df_traffic_N208], ignore_index = True)

# %%
#TODO if necessary, remove row multi-index
df_traffic
# Out:
#     Unnamed: 0_level_0            Link no  \
#     Unnamed: 0_level_1 Unnamed: 0_level_1
# 0                    0              N1-1L
# 1                    1              N1-1R
# 2                    2              N1-2L
# 3                    3              N1-2R
# 4                    4              N1-3L
# ..                 ...                ...
# 199                  0             N208-1
# 200                  1             N208-2
# 201                  2             N208-3
# 202                  3             N208-4
# 203                  4             N208-5
#
#                                                   Name Start location         \
#                                     Unnamed: 1_level_1            LRP Offset
# 0             Jatrabari - Int.with Z1101 (Left) (Left)           LRPS      0
# 1            Jatrabari - Int.with Z1101 (Left) (Right)           LRPS      0
# 2        Int.with Z1101 - Signboard (Left) R111 (Left)           LRPS    822
# ...

# %%
#save to csv
# df_traffic.to_csv("traffic_flows.csv")

# %%
for i in df_traffic.columns:
    print(i)
# Out:
# ('Unnamed: 0_level_0', 'Unnamed: 0_level_1')
# ('Link no', 'Unnamed: 0_level_1')
# ('Name', 'Unnamed: 1_level_1')
# ('Start location', 'LRP')
# ('Start location', 'Offset')
# ('Start location', 'Chainage')
# ('End location', 'LRP')
# ('End location', 'Offset')
# ('End location', 'Chainage')
# ('Length', '(Km)')
# ('Traffic Data', 'Heavy Truck')
# ('Traffic Data', 'Medium Truck')
# ('Traffic Data', 'Small Truck')
# ('Traffic Data', 'Large Bus')
# ('Traffic Data', 'Medium Bus')
# ('Traffic Data', 'Micro Bus')
# ('Traffic Data', 'Utility')
# ('Traffic Data', 'Car')
# ('Traffic Data', 'Auto Rickshaw')
# ('Traffic Data', 'Motor Cycle')
# ('Traffic Data', 'Bi-Cycle')
# ('Traffic Data', 'Cycle Rickshaw')
# ('Traffic Data', 'Cart')
# ('Total', 'Motorized')
# ('Total', 'Non Motorized')
# ('Total', 'Total AADT')
# ('Traffic', '(AADT)')

# %%
# Out:
# 0      N1-1
# 1      N1-1
# 2      N1-2
# 3      N1-2
# 4      N1-3
#        ...
# 100    N1-6
# 101    N1-6
# 102    N1-6
# 103    N1-6
# 104    N1-6
# Name: (Link no, Unnamed: 0_level_1), Length: 105, dtype: object

# %%
df_traffic_N1
# Out:
#     Unnamed: 0_level_0            Link no  \
#     Unnamed: 0_level_1 Unnamed: 0_level_1
# 0                    0               N1-1
# 1                    1               N1-1
# 2                    2               N1-2
# 3                    3               N1-2
# 4                    4               N1-3
# ..                 ...                ...
# 100                100               N1-6
# 101                101               N1-6
# 102                102               N1-6
# 103                103               N1-6
# 104                104               N1-6
#
#                                                Name Start location         \
#                                  Unnamed: 1_level_1            LRP Offset
# 0          Jatrabari - Int.with Z1101 (Left) (Left)           LRPS      0
# 1         Jatrabari - Int.with Z1101 (Left) (Right)           LRPS      0
# 2     Int.with Z1101 - Signboard (Left) R111 (Left)           LRPS    822
# ...

# %%
duplicates = df_traffic_N1[df_traffic_N1.duplicated([('Link no', 'Unnamed: 0_level_1')])]

# %%
duplicates
# Out:
#     Unnamed: 0_level_0            Link no  \
#     Unnamed: 0_level_1 Unnamed: 0_level_1
# 1                    1               N1-1
# 3                    3               N1-2
# 5                    5               N1-3
# 7                    7               N1-4
# 9                    9               N1-5
# ..                 ...                ...
# 100                100               N1-6
# 101                101               N1-6
# 102                102               N1-6
# 103                103               N1-6
# 104                104               N1-6
#
#                                                Name Start location         \
#                                  Unnamed: 1_level_1            LRP Offset
# 1         Jatrabari - Int.with Z1101 (Left) (Right)           LRPS      0
# 3    Int.with Z1101 - Signboard (Left) R111 (Right)           LRPS    822
# 5           Signboard - Shimrail (Left)R110 (Right)           LRPS   4175
# ...

# %%
duplicates.reset_index()
# Out:
#    index Unnamed: 0_level_0            Link no  \
#          Unnamed: 0_level_1 Unnamed: 0_level_1
# 0      1                  1               N1-1
# 1      3                  3               N1-2
# 2      5                  5               N1-3
# 3      7                  7               N1-4
# 4      9                  9               N1-5
# ..   ...                ...                ...
# 64   100                100               N1-6
# 65   101                101               N1-6
# 66   102                102               N1-6
# 67   103                103               N1-6
# 68   104                104               N1-6
#
#                                               Name Start location         \
#                                 Unnamed: 1_level_1            LRP Offset
# 0        Jatrabari - Int.with Z1101 (Left) (Right)           LRPS      0
# 1   Int.with Z1101 - Signboard (Left) R111 (Right)           LRPS    822
# ...

# %%
name = subset.loc[index, 'name']

# %%
subset = duplicates.loc[((duplicates['...']))]
