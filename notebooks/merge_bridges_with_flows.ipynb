# %%
import numpy as np
import pandas as pd

# %%
# read dataframe
df_bridges = pd.read_csv('../data/bridges_cleaned.csv')

# %%
df_bridges = df_bridges.drop(["Unnamed: 0", "index"], axis='columns')

# %%
# read sourcesink dataframe
df_sourcesinks = pd.read_csv('../data/sourcesinks.csv')

# %%
df_sourcesinks = df_sourcesinks.drop(["Unnamed: 0", 'Start_LRP', 'End_LRP'], axis = 'columns')

# %%
df_sourcesinks.rename({"Road":"road", "Name":"name", "Average Chainage":"km"}, axis = 1, inplace = True)

# %%
df_sourcesinks['type'] = 'sourcesink'
df_sourcesinks['length'] = 0
df_sourcesinks['condition'] = np.nan
df_sourcesinks['model_type'] = 'sourcesink'
df_sourcesinks['lat'] = np.nan
df_sourcesinks['lon'] = np.nan

# %%
new_bridge_columns = ['Total Cargo', 'Total People', 'Total Transport', 'Total Transport Weight', 'SourceSink Cargo Weight', 'SourceSink People Weight']

# %%
for column in new_bridge_columns:
    df_bridges[column] = np.nan

# %%
# get the dataframes which needs to be merged
frames = [df_bridges, df_sourcesinks]
# merge dataframes into df
df = pd.concat(frames)

# %%
df
# Out:
#     road      km              type  \
# 0     N1   0.000        sourcesink
# 1     N1   1.800       Box Culvert
# 2     N1   4.925       Box Culvert
# 3     N1   8.976  PC Girder Bridge
# 4     N1  10.543       Box Culvert
# ..   ...     ...               ...
# 30  N204   0.000        sourcesink
# 31  N207  67.985        sourcesink
# 32  N207   0.000        sourcesink
# 33  N208  57.495        sourcesink
# 34  N208   0.000        sourcesink
#
#                                              name  length condition  \
# 0                                      sourcesink     0.0       NaN
# 1                                               .    11.3         A
# 2                                               .     6.6         A
# 3                       KANCHPUR PC GIRDER BRIDGE   397.0         C
# 4                            KATCHPUR BOX CULVERT     8.0         B
# ..                                            ...     ...       ...
# 30       Jagadishpur-Chunarughat (Int.with Z2008)     0.0       NaN
# 31            Moulvibazar (Int.with N208)-Sherpur     0.0       NaN
# 32            Mirpur-Natun Bazar (Int.with Z2008)     0.0       NaN
# 33  Royal City Chottor(int.with N210)-Int.with N2     0.0       NaN
# 34                     Moulvibazar-Int.with Z2002     0.0       NaN
#
#           lat        lon  model_type  Total Cargo  Total People  \
# 0   23.706028  90.443333  sourcesink          NaN           NaN
# 1   23.698739  90.458861      bridge          NaN           NaN
# 2   23.694664  90.487775      bridge          NaN           NaN
# 3   23.705060  90.523214      bridge          NaN           NaN
# 4   23.696400  90.535099      bridge          NaN           NaN
# ..        ...        ...         ...          ...           ...
# 30        NaN        NaN  sourcesink        366.0        1905.0
# 31        NaN        NaN  sourcesink        766.0        4272.0
# 32        NaN        NaN  sourcesink        766.0        4272.0
# 33        NaN        NaN  sourcesink       2191.0        7297.0
# 34        NaN        NaN  sourcesink        964.0        6550.0
#
#     Total Transport  Total Transport Weight  SourceSink Cargo Weight  \
# 0               NaN                     NaN                      NaN
# 1               NaN                     NaN                      NaN
# 2               NaN                     NaN                      NaN
# 3               NaN                     NaN                      NaN
# 4               NaN                     NaN                      NaN
# ..              ...                     ...                      ...
# 30           2271.0                0.001436                 0.002251
# 31           5038.0                0.003186                 0.004711
# 32           5038.0                0.003186                 0.004711
# 33           9488.0                0.006001                 0.013474
# 34           7514.0                0.004752                 0.005928
#
#     SourceSink People Weight
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ..                       ...
# 30                  0.006471
# 31                  0.014511
# 32                  0.014511
# 33                  0.024786
# 34                  0.022249
#
# [19250 rows x 15 columns]

# %%
# sort values
df = df.sort_values(by=['road', 'km'])
# reset index
df = df.reset_index(drop=True)

# %%
duplicates = df[df.duplicated(subset=['road', 'km'], keep = False)]

# %%
duplicates = duplicates[duplicates['type'] == 'sourcesink']

# %%
duplicates
# Out:
#       road       km        type  \
# 0       N1    0.000  sourcesink
# 1       N1    0.000  sourcesink
# 650     N1  462.254  sourcesink
# 651     N1  462.254  sourcesink
# 654   N102    0.000  sourcesink
# 655   N102    0.000  sourcesink
# 750   N104    0.000  sourcesink
# 751   N104    0.000  sourcesink
# 792   N104   49.630  sourcesink
# 793   N104   49.630  sourcesink
# 794   N105    0.000  sourcesink
# 795   N105    0.000  sourcesink
# 1046    N2    0.000  sourcesink
# 1047    N2    0.000  sourcesink
# 1517    N2  286.516  sourcesink
# 1518    N2  286.516  sourcesink
# 1521  N204    0.000  sourcesink
# 1522  N204    0.000  sourcesink
# 1555  N204   34.421  sourcesink
# 1556  N204   34.421  sourcesink
# 1567  N207    0.000  sourcesink
# 1568  N207    0.000  sourcesink
# 1636  N207   67.985  sourcesink
# 1637  N207   67.985  sourcesink
# 1638  N208    0.000  sourcesink
# 1639  N208    0.000  sourcesink
# 1730  N208   57.495  sourcesink
# 1731  N208   57.495  sourcesink
# 3432    N8    0.000  sourcesink
# 3433    N8    0.000  sourcesink
# 3640    N8  205.127  sourcesink
# 3641    N8  205.127  sourcesink
#
#                                                    name  length condition  \
# 0                                            sourcesink     0.0       NaN
# 1              Jatrabari - Int.with Z1101 (Left) (Left)     0.0       NaN
# 650                                          sourcesink     0.0       NaN
# 651                              Whykong Z1133 - Teknaf     0.0       NaN
# 654                                          sourcesink     0.0       NaN
# 655     Mainamati-Kangsanagar (Intersection with Z1219)     0.0       NaN
# 750                                          sourcesink     0.0       NaN
# 751   Feni (Trank Road)-Feni (Mohipal Chourasta) Int...     0.0       NaN
# 792                                          sourcesink     0.0       NaN
# 793                     Maijdee(Int.with Z1429)-Sonapur     0.0       NaN
# 794                                          sourcesink     0.0       NaN
# 795   Madanpur (13th km of N1)-Nayapur, Bostail (Int...     0.0       NaN
# 1046                                         sourcesink     0.0       NaN
# 1047                    Katchpur-Tarabo (Int with R201)     0.0       NaN
# 1517                                         sourcesink     0.0       NaN
# 1518                     Tamabil(Int.with N212)-Jaflong     0.0       NaN
# 1521                                         sourcesink     0.0       NaN
# 1522           Jagadishpur-Chunarughat (Int.with Z2008)     0.0       NaN
# 1555                                         sourcesink     0.0       NaN
# 1556          Chunarughat (Int.with Z2008)-Shaisthaganj     0.0       NaN
# 1567                                         sourcesink     0.0       NaN
# 1568                Mirpur-Natun Bazar (Int.with Z2008)     0.0       NaN
# 1636                                         sourcesink     0.0       NaN
# 1637                Moulvibazar (Int.with N208)-Sherpur     0.0       NaN
# 1638                                         sourcesink     0.0       NaN
# 1639                         Moulvibazar-Int.with Z2002     0.0       NaN
# 1730                                         sourcesink     0.0       NaN
# 1731      Royal City Chottor(int.with N210)-Int.with N2     0.0       NaN
# 3432                                         sourcesink     0.0       NaN
# 3433                   Jatrabari-Jurain (int.with R810)     0.0       NaN
# 3640                                         sourcesink     0.0       NaN
# 3641              Lebukhali (Int. with Z8806)-End of N8     0.0       NaN
#
#             lat        lon  model_type  Total Cargo  Total People  \
# 0     23.706028  90.443333  sourcesink          NaN           NaN
# 1           NaN        NaN  sourcesink       7880.0       11356.0
# 650   20.862917  92.298083  sourcesink          NaN           NaN
# 651         NaN        NaN  sourcesink        616.0        4065.0
# 654   23.478972  91.118194  sourcesink          NaN           NaN
# 655         NaN        NaN  sourcesink       1737.0        7362.0
# 750   23.009667  91.399416  sourcesink          NaN           NaN
# 751         NaN        NaN  sourcesink       1171.0        6628.0
# 792   22.825749  91.101444  sourcesink          NaN           NaN
# 793         NaN        NaN  sourcesink       1190.0        6708.0
# 794   23.690416  90.546611  sourcesink          NaN           NaN
# 795         NaN        NaN  sourcesink       4999.0        8112.0
# 1046  23.705917  90.521444  sourcesink          NaN           NaN
# 1047        NaN        NaN  sourcesink       6710.0       16598.0
# 1517  25.157056  92.017638  sourcesink          NaN           NaN
# 1518        NaN        NaN  sourcesink       2031.0        2712.0
# 1521  24.147916  91.346611  sourcesink          NaN           NaN
# 1522        NaN        NaN  sourcesink        366.0        1905.0
# 1555  24.267388  91.477138  sourcesink          NaN           NaN
# 1556        NaN        NaN  sourcesink        366.0        1905.0
# 1567  24.294861  91.510250  sourcesink          NaN           NaN
# 1568        NaN        NaN  sourcesink        766.0        4272.0
# 1636  24.626333  91.677527  sourcesink          NaN           NaN
# 1637        NaN        NaN  sourcesink        766.0        4272.0
# 1638  24.471360  91.765556  sourcesink          NaN           NaN
# 1639        NaN        NaN  sourcesink        964.0        6550.0
# 1730  24.877555  91.875360  sourcesink          NaN           NaN
# 1731        NaN        NaN  sourcesink       2191.0        7297.0
# 3432  23.702139  90.435361  sourcesink          NaN           NaN
# 3433        NaN        NaN  sourcesink       3677.0       17946.0
# 3640  22.359722  90.318610  sourcesink          NaN           NaN
# 3641        NaN        NaN  sourcesink        955.0        3533.0
#
#       Total Transport  Total Transport Weight  SourceSink Cargo Weight  \
# 0                 NaN                     NaN                      NaN
# 1             19236.0                0.012165                 0.048459
# 650               NaN                     NaN                      NaN
# 651            4681.0                0.002960                 0.003788
# 654               NaN                     NaN                      NaN
# 655            9099.0                0.005754                 0.010682
# 750               NaN                     NaN                      NaN
# 751            7799.0                0.004932                 0.007201
# 792               NaN                     NaN                      NaN
# 793            7898.0                0.004995                 0.007318
# 794               NaN                     NaN                      NaN
# 795           13111.0                0.008292                 0.030742
# 1046              NaN                     NaN                      NaN
# 1047          23308.0                0.014741                 0.041264
# 1517              NaN                     NaN                      NaN
# 1518           4743.0                0.003000                 0.012490
# 1521              NaN                     NaN                      NaN
# 1522           2271.0                0.001436                 0.002251
# 1555              NaN                     NaN                      NaN
# 1556           2271.0                0.001436                 0.002251
# 1567              NaN                     NaN                      NaN
# 1568           5038.0                0.003186                 0.004711
# 1636              NaN                     NaN                      NaN
# 1637           5038.0                0.003186                 0.004711
# 1638              NaN                     NaN                      NaN
# 1639           7514.0                0.004752                 0.005928
# 1730              NaN                     NaN                      NaN
# 1731           9488.0                0.006001                 0.013474
# 3432              NaN                     NaN                      NaN
# 3433          21623.0                0.013675                 0.022612
# 3640              NaN                     NaN                      NaN
# 3641           4488.0                0.002838                 0.005873
#
#       SourceSink People Weight
# 0                          NaN
# 1                     0.038574
# 650                        NaN
# 651                   0.013808
# 654                        NaN
# 655                   0.025007
# 750                        NaN
# 751                   0.022514
# 792                        NaN
# 793                   0.022785
# 794                        NaN
# 795                   0.027554
# 1046                       NaN
# 1047                  0.056379
# 1517                       NaN
# 1518                  0.009212
# 1521                       NaN
# 1522                  0.006471
# 1555                       NaN
# 1556                  0.006471
# 1567                       NaN
# 1568                  0.014511
# 1636                       NaN
# 1637                  0.014511
# 1638                       NaN
# 1639                  0.022249
# 1730                       NaN
# 1731                  0.024786
# 3432                       NaN
# 3433                  0.060958
# 3640                       NaN
# 3641                  0.012001

# %%
def get_pairs(): 
    duplicates = df[df.duplicated(subset=['road', 'km'])]
    duplicates = duplicates[duplicates['type'] == 'sourcesink']

    for index, row in duplicates.iterrows(): 
        # get road
        road = df.loc[index, 'road']
        # get chainage
        chainage = df.loc[index, 'km']
        # define a subset of duplicates based on the road and chainage
        subset = df.loc[((df['road'] == road) & (df['km'] == chainage))]

        df.at[index, 'lat'] = df.at[index-1, 'lat']
        df.at[index, 'lon'] = df.at[index-1, 'lon']

# %%
get_pairs()

# %%
# drop old one with less information
df = df.drop_duplicates(subset=['road', 'km'], keep='last')

# %%
df
# Out:
#         road      km                   type  \
# 1         N1  0.0000             sourcesink
# 2         N1  1.8000            Box Culvert
# 3         N1  2.4985             sourcesink
# 4         N1  4.9250            Box Culvert
# 5         N1  5.6780             sourcesink
# ...      ...     ...                    ...
# 19245  Z8943  6.6920  Truss with Steel Deck
# 19246  Z8943  6.7670            Box Culvert
# 19247  Z8943  8.1040      RCC Girder Bridge
# 19248  Z8943  8.6090  Truss with Steel Deck
# 19249  Z8943  8.8000             sourcesink
#
#                                                 name  length condition  \
# 1           Jatrabari - Int.with Z1101 (Left) (Left)    0.00       NaN
# 2                                                  .   11.30         A
# 3      Int.with Z1101 - Signboard (Left) R111 (Left)    0.00       NaN
# 4                                                  .    6.60         A
# 5             Signboard - Shimrail (Left)R110 (Left)    0.00       NaN
# ...                                              ...     ...       ...
# 19245                                              .   31.07         A
# 19246                                              .    1.93         A
# 19247                                              .   12.00         C
# 19248                                              .   31.07         A
# 19249                                     sourcesink    0.00       NaN
#
#              lat        lon  model_type  Total Cargo  Total People  \
# 1      23.706028  90.443333  sourcesink       7880.0       11356.0
# 2      23.698739  90.458861      bridge          NaN           NaN
# 3            NaN        NaN  sourcesink       7880.0       11356.0
# 4      23.694664  90.487775      bridge          NaN           NaN
# 5            NaN        NaN  sourcesink       4831.5       11035.0
# ...          ...        ...         ...          ...           ...
# 19245  22.428621  90.788543      bridge          NaN           NaN
# 19246  22.428872  90.787904      bridge          NaN           NaN
# 19247  22.430219  90.775203      bridge          NaN           NaN
# 19248  22.428889  90.788333      bridge          NaN           NaN
# 19249  22.430166  90.768916  sourcesink          NaN           NaN
#
#        Total Transport  Total Transport Weight  SourceSink Cargo Weight  \
# 1              19236.0                0.012165                 0.048459
# 2                  NaN                     NaN                      NaN
# 3              19236.0                0.012165                 0.048459
# 4                  NaN                     NaN                      NaN
# 5              15866.5                0.010034                 0.029712
# ...                ...                     ...                      ...
# 19245              NaN                     NaN                      NaN
# 19246              NaN                     NaN                      NaN
# 19247              NaN                     NaN                      NaN
# 19248              NaN                     NaN                      NaN
# 19249              NaN                     NaN                      NaN
#
#        SourceSink People Weight
# 1                      0.038574
# 2                           NaN
# 3                      0.038574
# 4                           NaN
# 5                      0.037483
# ...                         ...
# 19245                       NaN
# 19246                       NaN
# 19247                       NaN
# 19248                       NaN
# 19249                       NaN
#
# [19202 rows x 15 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19202 entries, 1 to 19249
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   road                      19202 non-null  object
#  1   km                        19202 non-null  float64
#  2   type                      19202 non-null  object
#  3   name                      19202 non-null  object
#  4   length                    19202 non-null  float64
#  5   condition                 17490 non-null  object
#  6   lat                       19183 non-null  float64
#  7   lon                       19183 non-null  float64
#  8   model_type                19202 non-null  object
#  9   Total Cargo               35 non-null     float64
#  10  Total People              35 non-null     float64
#  11  Total Transport           35 non-null     float64
#  12  Total Transport Weight    35 non-null     float64
#  13  SourceSink Cargo Weight   35 non-null     float64
#  14  SourceSink People Weight  35 non-null     float64
# dtypes: float64(10), object(5)
# memory usage: 2.3+ MB

# %%
missing = df[df.lat.isnull()]

# %%
missing
# Out:
#       road        km        type  \
# 3       N1    2.4985  sourcesink
# 5       N1    5.6780  sourcesink
# 6       N1    7.9720  sourcesink
# 8       N1   10.3495  sourcesink
# 19      N1   13.9355  sourcesink
# 26      N1   17.9895  sourcesink
# 33      N1   21.8040  sourcesink
# 42      N1   27.2500  sourcesink
# 49      N1   33.6035  sourcesink
# 56      N1   37.3685  sourcesink
# 133     N1  147.3490  sourcesink
# 139     N1  159.6335  sourcesink
# 186     N1  200.5025  sourcesink
# 214     N1  217.4040  sourcesink
# 747   N102   83.3820  sourcesink
# 842   N105   48.8810  sourcesink
# 1049    N2    2.3130  sourcesink
# 1050    N2    8.5935  sourcesink
# 1052    N2   11.5440  sourcesink
#
#                                                    name  length condition  \
# 3         Int.with Z1101 - Signboard (Left) R111 (Left)     0.0       NaN
# 5                Signboard - Shimrail (Left)R110 (Left)     0.0       NaN
# 6                   Shimrail - Katchpur (Left)N2 (Left)     0.0       NaN
# 8                 Katchpur - Madanpur (Left)N105 (Left)     0.0       NaN
# 19             Madanpur - Langalband (Left)Z1061 (Left)     0.0       NaN
# 26    Langalband - Mograpara Chowrasta (Left)Z1089 (...     0.0       NaN
# 33    Mograpara(Int.with Z1089)-Meghna Bridge West E...     0.0       NaN
# 42    Meghna Bridge Satrt-Bhaberchar (Left) z1063 (L...     0.0       NaN
# 49    Bhaberchar(Int.with Z1063)-Daudkandi Bridge (L...     0.0       NaN
# 56             Daudkandi Bridge- Daudkandi Z1062 (Left)     0.0       NaN
# 133   Feni (Int.with N104) - Feni Shahid Minar (Int....     0.0       NaN
# 139            Fazilpur Z1081 - Muhuriganj Z1032 (Left)     0.0       NaN
# 186           Baroirdala Z1086- Barabkunda Z1087 (Left)     0.0       NaN
# 214            Barabkunda Z1087-Fouzderhat Z1016 (Left)     0.0       NaN
# 747   Gathuria(Int. with N103)-Sarail(Kathihat, int....     0.0       NaN
# 842   Vogra Bypass(Int.with N3)-End of Road (Int.wit...     0.0       NaN
# 1049  Tarabo(Int with R 201)-Barpa(Int. with Z1090 L...     0.0       NaN
# 1050  Barpa(Int. with Z1090 LGED Road)-Bhulta (Int.w...     0.0       NaN
# 1052      Bhulta (Int.with R202)-Bhulta (Int.with R203)     0.0       NaN
#
#       lat  lon  model_type  Total Cargo  Total People  Total Transport  \
# 3     NaN  NaN  sourcesink       7880.0       11356.0          19236.0
# 5     NaN  NaN  sourcesink       4831.5       11035.0          15866.5
# 6     NaN  NaN  sourcesink       4556.5       11442.0          15998.5
# 8     NaN  NaN  sourcesink       8205.0       14361.0          22566.0
# 19    NaN  NaN  sourcesink       8205.0       14361.0          22566.0
# 26    NaN  NaN  sourcesink       8205.0       14361.0          22566.0
# 33    NaN  NaN  sourcesink       6516.5        7972.5          14489.0
# 42    NaN  NaN  sourcesink       6516.5        7972.5          14489.0
# 49    NaN  NaN  sourcesink       6516.5        7972.5          14489.0
# 56    NaN  NaN  sourcesink       6516.5        7972.5          14489.0
# 133   NaN  NaN  sourcesink       7712.5        6424.0          14136.5
# 139   NaN  NaN  sourcesink       7712.5        6424.0          14136.5
# 186   NaN  NaN  sourcesink       7554.0        7317.0          14871.0
# 214   NaN  NaN  sourcesink       7554.0        7317.0          14871.0
# 747   NaN  NaN  sourcesink       2602.0        8919.0          11521.0
# 842   NaN  NaN  sourcesink       5216.0        5157.0          10373.0
# 1049  NaN  NaN  sourcesink       6815.0       10430.0          17245.0
# 1050  NaN  NaN  sourcesink       6556.0       11192.0          17748.0
# 1052  NaN  NaN  sourcesink       6556.0       11192.0          17748.0
#
#       Total Transport Weight  SourceSink Cargo Weight  \
# 3                   0.012165                 0.048459
# 5                   0.010034                 0.029712
# 6                   0.010118                 0.028021
# 8                   0.014271                 0.050458
# 19                  0.014271                 0.050458
# 26                  0.014271                 0.050458
# 33                  0.009163                 0.040074
# 42                  0.009163                 0.040074
# 49                  0.009163                 0.040074
# 56                  0.009163                 0.040074
# 133                 0.008940                 0.047429
# 139                 0.008940                 0.047429
# 186                 0.009405                 0.046454
# 214                 0.009405                 0.046454
# 747                 0.007286                 0.016001
# 842                 0.006560                 0.032076
# 1049                0.010906                 0.041910
# 1050                0.011224                 0.040317
# 1052                0.011224                 0.040317
#
#       SourceSink People Weight
# 3                     0.038574
# 5                     0.037483
# 6                     0.038866
# 8                     0.048781
# 19                    0.048781
# 26                    0.048781
# 33                    0.027081
# 42                    0.027081
# 49                    0.027081
# 56                    0.027081
# 133                   0.021821
# 139                   0.021821
# 186                   0.024854
# 214                   0.024854
# 747                   0.030296
# 842                   0.017517
# 1049                  0.035428
# 1050                  0.038016
# 1052                  0.038016

# %%
df_roads = pd.read_csv('../data/roads.csv')

# %%
df_roads
# Out:
#         road  chainage      lrp        lat        lon  gap       type  \
# 0         N1     0.000     LRPS  23.706028  90.443333  NaN     Others
# 1         N1     0.814    LRPSa  23.702917  90.450417  NaN    Culvert
# 2         N1     0.822    LRPSb  23.702778  90.450472  NaN  CrossRoad
# 3         N1     1.000   LRP001  23.702139  90.451972  NaN     KmPost
# 4         N1     2.000   LRP002  23.697889  90.460583  NaN     KmPost
# ...      ...       ...      ...        ...        ...  ...        ...
# 51343  Z8943     7.000   LRP007  22.429499  90.785722  NaN     KmPost
# 51344  Z8943     8.000   LRP008  22.430110  90.776333  NaN     KmPost
# 51345  Z8943     8.133  LRP008a  22.430249  90.774888   BS     Bridge
# 51346  Z8943     8.151  LRP008b  22.430249  90.774860   BE     Bridge
# 51347  Z8943     8.800     LRPE  22.430166  90.768916  NaN     Others
#
#                                                     name
# 0      Start of Road  after Jatrabari Flyover infront...
# 1                                            Box Culvert
# 2                                Intersection with Z1101
# 3                                        Km post missing
# 4                                        Km post missing
# ...                                                  ...
# 51343                                    Km Post Missing
# 51344                                    Km Post Missing
# 51345                                    Start of Bridge
# 51346                                      End of Bridge
# 51347  End at Kunjerhat Bazar and intersct with R890,...
#
# [51348 rows x 8 columns]

# %%
for index in missing.index: 
    # get chainage of missing value
    get_chainage = df.loc[index, 'km']
    # get road name of missing value
    road_name = df.loc[index, 'road']
    # get road subset
    road_subset = df_roads[df_roads['road'] == road_name]
    # get similar chainage in road dataset
    if road_name == 'N1' or road_name == 'N2' or road_name == 'N8': 
        similar_chainage = road_subset[road_subset['chainage'].between(get_chainage-0.5, get_chainage+0.5)]
    else: 
        similar_chainage = road_subset[road_subset['chainage'].between(get_chainage-5, get_chainage+5)]
    # get latitude and longitude of last row in subset of similar chainage
    lat = similar_chainage.at[similar_chainage.index[-1], 'lat']
    lon = similar_chainage.at[similar_chainage.index[-1], 'lon']
    # assign latitude and longitude to missing row
    df.loc[index, 'lat'] = lat
    df.loc[index, 'lon'] = lon

# %%
df
# Out:
#         road      km                   type  \
# 1         N1  0.0000             sourcesink
# 2         N1  1.8000            Box Culvert
# 3         N1  2.4985             sourcesink
# 4         N1  4.9250            Box Culvert
# 5         N1  5.6780             sourcesink
# ...      ...     ...                    ...
# 19245  Z8943  6.6920  Truss with Steel Deck
# 19246  Z8943  6.7670            Box Culvert
# 19247  Z8943  8.1040      RCC Girder Bridge
# 19248  Z8943  8.6090  Truss with Steel Deck
# 19249  Z8943  8.8000             sourcesink
#
#                                                 name  length condition  \
# 1           Jatrabari - Int.with Z1101 (Left) (Left)    0.00       NaN
# 2                                                  .   11.30         A
# 3      Int.with Z1101 - Signboard (Left) R111 (Left)    0.00       NaN
# 4                                                  .    6.60         A
# 5             Signboard - Shimrail (Left)R110 (Left)    0.00       NaN
# ...                                              ...     ...       ...
# 19245                                              .   31.07         A
# 19246                                              .    1.93         A
# 19247                                              .   12.00         C
# 19248                                              .   31.07         A
# 19249                                     sourcesink    0.00       NaN
#
#              lat        lon  model_type  Total Cargo  Total People  \
# 1      23.706028  90.443333  sourcesink       7880.0       11356.0
# 2      23.698739  90.458861      bridge          NaN           NaN
# 3      23.697361  90.461667  sourcesink       7880.0       11356.0
# 4      23.694664  90.487775      bridge          NaN           NaN
# 5      23.695916  90.498194  sourcesink       4831.5       11035.0
# ...          ...        ...         ...          ...           ...
# 19245  22.428621  90.788543      bridge          NaN           NaN
# 19246  22.428872  90.787904      bridge          NaN           NaN
# 19247  22.430219  90.775203      bridge          NaN           NaN
# 19248  22.428889  90.788333      bridge          NaN           NaN
# 19249  22.430166  90.768916  sourcesink          NaN           NaN
#
#        Total Transport  Total Transport Weight  SourceSink Cargo Weight  \
# 1              19236.0                0.012165                 0.048459
# 2                  NaN                     NaN                      NaN
# 3              19236.0                0.012165                 0.048459
# 4                  NaN                     NaN                      NaN
# 5              15866.5                0.010034                 0.029712
# ...                ...                     ...                      ...
# 19245              NaN                     NaN                      NaN
# 19246              NaN                     NaN                      NaN
# 19247              NaN                     NaN                      NaN
# 19248              NaN                     NaN                      NaN
# 19249              NaN                     NaN                      NaN
#
#        SourceSink People Weight
# 1                      0.038574
# 2                           NaN
# 3                      0.038574
# 4                           NaN
# 5                      0.037483
# ...                         ...
# 19245                       NaN
# 19246                       NaN
# 19247                       NaN
# 19248                       NaN
# 19249                       NaN
#
# [19202 rows x 15 columns]

# %%
df_intersections = pd.read_csv('../data/intersections.csv')
# get all intersected roads
intersections = df_intersections['intersec_to'].unique().tolist()
# remove nan if present
intersections = [x for x in intersections if str(x) != 'nan']

# keep all bridges in roads that intersect
df = df[df['road'].isin(intersections)]

# %% [markdown]
# # Reiterate over sourcesinks and get new weights

# %%
df['Total Transport'] = df['Total Cargo'] + df['Total People']
df['Total Transport Weight'] = df['Total Transport']/sum(df['Total Transport'])
# Out:
# /var/folders/g4/8z1prdqs5l3dj5xzv765t_sc0000gn/T/ipykernel_5279/2496406974.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Total Transport'] = df['Total Cargo'] + df['Total People']
# /var/folders/g4/8z1prdqs5l3dj5xzv765t_sc0000gn/T/ipykernel_5279/2496406974.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Total Transport Weight'] = df['Total Transport']/sum(df['Total Transport'])

# %%
def determine_sourcesinks(df, n_sourcesinks):
    # subset data on sourcesinks
    df = df[df['type'] == 'sourcesink']
    sort_df = df.sort_values(by='Total Transport Weight', ascending=False).reset_index(drop=True)
    sourcesinks = sort_df.iloc[:n_sourcesinks]
    sourcesinks['SourceSink Cargo Weight'] = sourcesinks['Total Cargo']/sum(sourcesinks['Total Cargo'])
    sourcesinks['SourceSink People Weight'] = sourcesinks['Total People']/sum(sourcesinks['Total People'])
    return sourcesinks

# %%
sourcesinks = determine_sourcesinks(df, 20)
sourcesinks
# Out:
# /var/folders/g4/8z1prdqs5l3dj5xzv765t_sc0000gn/T/ipykernel_5279/6247097.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sourcesinks['SourceSink Cargo Weight'] = sourcesinks['Total Cargo']/sum(sourcesinks['Total Cargo'])
# /var/folders/g4/8z1prdqs5l3dj5xzv765t_sc0000gn/T/ipykernel_5279/6247097.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sourcesinks['SourceSink People Weight'] = sourcesinks['Total People']/sum(sourcesinks['Total People'])
#     road        km        type  \
# 0     N1    0.0000  sourcesink
# 1     N1    2.4985  sourcesink
# 2     N1    5.6780  sourcesink
# 3     N1    7.9720  sourcesink
# 4     N1   10.3495  sourcesink
# 5     N1   13.9355  sourcesink
# 6     N1   17.9895  sourcesink
# 7     N1   21.8040  sourcesink
# 8     N1   27.2500  sourcesink
# 9     N1   33.6035  sourcesink
# 10    N1   37.3685  sourcesink
# 11    N1  147.3490  sourcesink
# 12    N1  159.6335  sourcesink
# 13    N1  200.5025  sourcesink
# 14    N1  217.4040  sourcesink
# 15    N1  462.2540  sourcesink
# 16  N102    0.0000  sourcesink
# 17  N102   82.6820  sourcesink
# 18  N102   83.3820  sourcesink
# 19  N104    0.0000  sourcesink
#
#                                                  name  length condition  \
# 0            Jatrabari - Int.with Z1101 (Left) (Left)     0.0       NaN
# 1       Int.with Z1101 - Signboard (Left) R111 (Left)     0.0       NaN
# 2              Signboard - Shimrail (Left)R110 (Left)     0.0       NaN
# 3                 Shimrail - Katchpur (Left)N2 (Left)     0.0       NaN
# 4               Katchpur - Madanpur (Left)N105 (Left)     0.0       NaN
# 5            Madanpur - Langalband (Left)Z1061 (Left)     0.0       NaN
# 6   Langalband - Mograpara Chowrasta (Left)Z1089 (...     0.0       NaN
# 7   Mograpara(Int.with Z1089)-Meghna Bridge West E...     0.0       NaN
# 8   Meghna Bridge Satrt-Bhaberchar (Left) z1063 (L...     0.0       NaN
# 9   Bhaberchar(Int.with Z1063)-Daudkandi Bridge (L...     0.0       NaN
# 10           Daudkandi Bridge- Daudkandi Z1062 (Left)     0.0       NaN
# 11  Feni (Int.with N104) - Feni Shahid Minar (Int....     0.0       NaN
# 12           Fazilpur Z1081 - Muhuriganj Z1032 (Left)     0.0       NaN
# 13          Baroirdala Z1086- Barabkunda Z1087 (Left)     0.0       NaN
# 14           Barabkunda Z1087-Fouzderhat Z1016 (Left)     0.0       NaN
# 15                             Whykong Z1133 - Teknaf     0.0       NaN
# 16    Mainamati-Kangsanagar (Intersection with Z1219)     0.0       NaN
# 17                                         sourcesink     0.0       NaN
# 18  Gathuria(Int. with N103)-Sarail(Kathihat, int....     0.0       NaN
# 19  Feni (Trank Road)-Feni (Mohipal Chourasta) Int...     0.0       NaN
#
#           lat        lon  model_type  Total Cargo  Total People  \
# 0   23.706028  90.443333  sourcesink       7880.0       11356.0
# 1   23.697361  90.461667  sourcesink       7880.0       11356.0
# 2   23.695916  90.498194  sourcesink       4831.5       11035.0
# 3   23.704583  90.518833  sourcesink       4556.5       11442.0
# 4   23.696639  90.534805  sourcesink       8205.0       14361.0
# 5   23.678166  90.555611  sourcesink       8205.0       14361.0
# 6   23.650694  90.582999  sourcesink       8205.0       14361.0
# 7   23.620472  90.607972  sourcesink       6516.5        7972.5
# 8   23.582583  90.638139  sourcesink       6516.5        7972.5
# 9   23.542583  90.674944  sourcesink       6516.5        7972.5
# 10  23.530777  90.709028  sourcesink       6516.5        7972.5
# 11  22.996389  91.399805  sourcesink       7712.5        6424.0
# 12  22.949777  91.498027  sourcesink       7712.5        6424.0
# 13  22.623472  91.655306  sourcesink       7554.0        7317.0
# 14  22.486944  91.719277  sourcesink       7554.0        7317.0
# 15  20.862917  92.298083  sourcesink        616.0        4065.0
# 16  23.478972  91.118194  sourcesink       1737.0        7362.0
# 17  24.050611  91.114667  sourcesink          NaN           NaN
# 18  24.050611  91.114667  sourcesink       2602.0        8919.0
# 19  23.009667  91.399416  sourcesink       1171.0        6628.0
#
#     Total Transport  Total Transport Weight  SourceSink Cargo Weight  \
# 0           19236.0                     NaN                      NaN
# 1           19236.0                     NaN                      NaN
# 2           15866.5                     NaN                      NaN
# 3           15998.5                     NaN                      NaN
# 4           22566.0                     NaN                      NaN
# 5           22566.0                     NaN                      NaN
# 6           22566.0                     NaN                      NaN
# 7           14489.0                     NaN                      NaN
# 8           14489.0                     NaN                      NaN
# 9           14489.0                     NaN                      NaN
# 10          14489.0                     NaN                      NaN
# 11          14136.5                     NaN                      NaN
# 12          14136.5                     NaN                      NaN
# 13          14871.0                     NaN                      NaN
# 14          14871.0                     NaN                      NaN
# 15           4681.0                     NaN                      NaN
# 16           9099.0                     NaN                      NaN
# 17              NaN                     NaN                      NaN
# 18          11521.0                     NaN                      NaN
# 19           7799.0                     NaN                      NaN
#
#     SourceSink People Weight
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# 5                        NaN
# 6                        NaN
# 7                        NaN
# 8                        NaN
# 9                        NaN
# 10                       NaN
# 11                       NaN
# 12                       NaN
# 13                       NaN
# 14                       NaN
# 15                       NaN
# 16                       NaN
# 17                       NaN
# 18                       NaN
# 19                       NaN

# %%
# get roads
roads = sourcesinks['road'].unique().tolist()
# get all sourcesink rows
df_only_sourcesink = df[df['type'] == 'sourcesink']
df_only_sourcesink
# Out:
#       road        km        type  \
# 1       N1    0.0000  sourcesink
# 3       N1    2.4985  sourcesink
# 5       N1    5.6780  sourcesink
# 6       N1    7.9720  sourcesink
# 8       N1   10.3495  sourcesink
# 19      N1   13.9355  sourcesink
# 26      N1   17.9895  sourcesink
# 33      N1   21.8040  sourcesink
# 42      N1   27.2500  sourcesink
# 49      N1   33.6035  sourcesink
# 56      N1   37.3685  sourcesink
# 133     N1  147.3490  sourcesink
# 139     N1  159.6335  sourcesink
# 186     N1  200.5025  sourcesink
# 214     N1  217.4040  sourcesink
# 651     N1  462.2540  sourcesink
# 655   N102    0.0000  sourcesink
# 746   N102   82.6820  sourcesink
# 747   N102   83.3820  sourcesink
# 751   N104    0.0000  sourcesink
# 793   N104   49.6300  sourcesink
# 795   N105    0.0000  sourcesink
# 841   N105   48.8700  sourcesink
# 842   N105   48.8810  sourcesink
# 1047    N2    0.0000  sourcesink
# 1049    N2    2.3130  sourcesink
# 1050    N2    8.5935  sourcesink
# 1052    N2   11.5440  sourcesink
# 1518    N2  286.5160  sourcesink
# 1522  N204    0.0000  sourcesink
# 1556  N204   34.4210  sourcesink
# 1568  N207    0.0000  sourcesink
# 1637  N207   67.9850  sourcesink
# 1639  N208    0.0000  sourcesink
# 1731  N208   57.4950  sourcesink
# 3433    N8    0.0000  sourcesink
# 3641    N8  205.1270  sourcesink
#
#                                                    name  length condition  \
# 1              Jatrabari - Int.with Z1101 (Left) (Left)     0.0       NaN
# 3         Int.with Z1101 - Signboard (Left) R111 (Left)     0.0       NaN
# 5                Signboard - Shimrail (Left)R110 (Left)     0.0       NaN
# 6                   Shimrail - Katchpur (Left)N2 (Left)     0.0       NaN
# 8                 Katchpur - Madanpur (Left)N105 (Left)     0.0       NaN
# 19             Madanpur - Langalband (Left)Z1061 (Left)     0.0       NaN
# 26    Langalband - Mograpara Chowrasta (Left)Z1089 (...     0.0       NaN
# 33    Mograpara(Int.with Z1089)-Meghna Bridge West E...     0.0       NaN
# 42    Meghna Bridge Satrt-Bhaberchar (Left) z1063 (L...     0.0       NaN
# 49    Bhaberchar(Int.with Z1063)-Daudkandi Bridge (L...     0.0       NaN
# 56             Daudkandi Bridge- Daudkandi Z1062 (Left)     0.0       NaN
# 133   Feni (Int.with N104) - Feni Shahid Minar (Int....     0.0       NaN
# 139            Fazilpur Z1081 - Muhuriganj Z1032 (Left)     0.0       NaN
# 186           Baroirdala Z1086- Barabkunda Z1087 (Left)     0.0       NaN
# 214            Barabkunda Z1087-Fouzderhat Z1016 (Left)     0.0       NaN
# 651                              Whykong Z1133 - Teknaf     0.0       NaN
# 655     Mainamati-Kangsanagar (Intersection with Z1219)     0.0       NaN
# 746                                          sourcesink     0.0       NaN
# 747   Gathuria(Int. with N103)-Sarail(Kathihat, int....     0.0       NaN
# 751   Feni (Trank Road)-Feni (Mohipal Chourasta) Int...     0.0       NaN
# 793                     Maijdee(Int.with Z1429)-Sonapur     0.0       NaN
# 795   Madanpur (13th km of N1)-Nayapur, Bostail (Int...     0.0       NaN
# 841                                          sourcesink     0.0       NaN
# 842   Vogra Bypass(Int.with N3)-End of Road (Int.wit...     0.0       NaN
# 1047                    Katchpur-Tarabo (Int with R201)     0.0       NaN
# 1049  Tarabo(Int with R 201)-Barpa(Int. with Z1090 L...     0.0       NaN
# 1050  Barpa(Int. with Z1090 LGED Road)-Bhulta (Int.w...     0.0       NaN
# 1052      Bhulta (Int.with R202)-Bhulta (Int.with R203)     0.0       NaN
# 1518                     Tamabil(Int.with N212)-Jaflong     0.0       NaN
# 1522           Jagadishpur-Chunarughat (Int.with Z2008)     0.0       NaN
# 1556          Chunarughat (Int.with Z2008)-Shaisthaganj     0.0       NaN
# 1568                Mirpur-Natun Bazar (Int.with Z2008)     0.0       NaN
# 1637                Moulvibazar (Int.with N208)-Sherpur     0.0       NaN
# 1639                         Moulvibazar-Int.with Z2002     0.0       NaN
# 1731      Royal City Chottor(int.with N210)-Int.with N2     0.0       NaN
# 3433                   Jatrabari-Jurain (int.with R810)     0.0       NaN
# 3641              Lebukhali (Int. with Z8806)-End of N8     0.0       NaN
#
#             lat        lon  model_type  Total Cargo  Total People  \
# 1     23.706028  90.443333  sourcesink       7880.0       11356.0
# 3     23.697361  90.461667  sourcesink       7880.0       11356.0
# 5     23.695916  90.498194  sourcesink       4831.5       11035.0
# 6     23.704583  90.518833  sourcesink       4556.5       11442.0
# 8     23.696639  90.534805  sourcesink       8205.0       14361.0
# 19    23.678166  90.555611  sourcesink       8205.0       14361.0
# 26    23.650694  90.582999  sourcesink       8205.0       14361.0
# 33    23.620472  90.607972  sourcesink       6516.5        7972.5
# 42    23.582583  90.638139  sourcesink       6516.5        7972.5
# 49    23.542583  90.674944  sourcesink       6516.5        7972.5
# 56    23.530777  90.709028  sourcesink       6516.5        7972.5
# 133   22.996389  91.399805  sourcesink       7712.5        6424.0
# 139   22.949777  91.498027  sourcesink       7712.5        6424.0
# 186   22.623472  91.655306  sourcesink       7554.0        7317.0
# 214   22.486944  91.719277  sourcesink       7554.0        7317.0
# 651   20.862917  92.298083  sourcesink        616.0        4065.0
# 655   23.478972  91.118194  sourcesink       1737.0        7362.0
# 746   24.050611  91.114667  sourcesink          NaN           NaN
# 747   24.050611  91.114667  sourcesink       2602.0        8919.0
# 751   23.009667  91.399416  sourcesink       1171.0        6628.0
# 793   22.825749  91.101444  sourcesink       1190.0        6708.0
# 795   23.690416  90.546611  sourcesink       4999.0        8112.0
# 841   23.989527  90.358222  sourcesink          NaN           NaN
# 842   23.989527  90.358222  sourcesink       5216.0        5157.0
# 1047  23.705917  90.521444  sourcesink       6710.0       16598.0
# 1049  23.724944  90.513417  sourcesink       6815.0       10430.0
# 1050  23.763028  90.550389  sourcesink       6556.0       11192.0
# 1052  23.785666  90.570583  sourcesink       6556.0       11192.0
# 1518  25.157056  92.017638  sourcesink       2031.0        2712.0
# 1522  24.147916  91.346611  sourcesink        366.0        1905.0
# 1556  24.267388  91.477138  sourcesink        366.0        1905.0
# 1568  24.294861  91.510250  sourcesink        766.0        4272.0
# 1637  24.626333  91.677527  sourcesink        766.0        4272.0
# 1639  24.471360  91.765556  sourcesink        964.0        6550.0
# 1731  24.877555  91.875360  sourcesink       2191.0        7297.0
# 3433  23.702139  90.435361  sourcesink       3677.0       17946.0
# 3641  22.359722  90.318610  sourcesink        955.0        3533.0
#
#       Total Transport  Total Transport Weight  SourceSink Cargo Weight  \
# 1             19236.0                     NaN                 0.048459
# 3             19236.0                     NaN                 0.048459
# 5             15866.5                     NaN                 0.029712
# 6             15998.5                     NaN                 0.028021
# 8             22566.0                     NaN                 0.050458
# 19            22566.0                     NaN                 0.050458
# 26            22566.0                     NaN                 0.050458
# 33            14489.0                     NaN                 0.040074
# 42            14489.0                     NaN                 0.040074
# 49            14489.0                     NaN                 0.040074
# 56            14489.0                     NaN                 0.040074
# 133           14136.5                     NaN                 0.047429
# 139           14136.5                     NaN                 0.047429
# 186           14871.0                     NaN                 0.046454
# 214           14871.0                     NaN                 0.046454
# 651            4681.0                     NaN                 0.003788
# 655            9099.0                     NaN                 0.010682
# 746               NaN                     NaN                      NaN
# 747           11521.0                     NaN                 0.016001
# 751            7799.0                     NaN                 0.007201
# 793            7898.0                     NaN                 0.007318
# 795           13111.0                     NaN                 0.030742
# 841               NaN                     NaN                      NaN
# 842           10373.0                     NaN                 0.032076
# 1047          23308.0                     NaN                 0.041264
# 1049          17245.0                     NaN                 0.041910
# 1050          17748.0                     NaN                 0.040317
# 1052          17748.0                     NaN                 0.040317
# 1518           4743.0                     NaN                 0.012490
# 1522           2271.0                     NaN                 0.002251
# 1556           2271.0                     NaN                 0.002251
# 1568           5038.0                     NaN                 0.004711
# 1637           5038.0                     NaN                 0.004711
# 1639           7514.0                     NaN                 0.005928
# 1731           9488.0                     NaN                 0.013474
# 3433          21623.0                     NaN                 0.022612
# 3641           4488.0                     NaN                 0.005873
#
#       SourceSink People Weight
# 1                     0.038574
# 3                     0.038574
# 5                     0.037483
# 6                     0.038866
# 8                     0.048781
# 19                    0.048781
# 26                    0.048781
# 33                    0.027081
# 42                    0.027081
# 49                    0.027081
# 56                    0.027081
# 133                   0.021821
# 139                   0.021821
# 186                   0.024854
# 214                   0.024854
# 651                   0.013808
# 655                   0.025007
# 746                        NaN
# 747                   0.030296
# 751                   0.022514
# 793                   0.022785
# 795                   0.027554
# 841                        NaN
# 842                   0.017517
# 1047                  0.056379
# 1049                  0.035428
# 1050                  0.038016
# 1052                  0.038016
# 1518                  0.009212
# 1522                  0.006471
# 1556                  0.006471
# 1568                  0.014511
# 1637                  0.014511
# 1639                  0.022249
# 1731                  0.024786
# 3433                  0.060958
# 3641                  0.012001

# %%
df_only_sourcesink = df_only_sourcesink.reset_index(drop = True)

# %%
df_only_sourcesink
# Out:
#     road        km        type  \
# 0     N1    0.0000  sourcesink
# 1     N1    2.4985  sourcesink
# 2     N1    5.6780  sourcesink
# 3     N1    7.9720  sourcesink
# 4     N1   10.3495  sourcesink
# 5     N1   13.9355  sourcesink
# 6     N1   17.9895  sourcesink
# 7     N1   21.8040  sourcesink
# 8     N1   27.2500  sourcesink
# 9     N1   33.6035  sourcesink
# 10    N1   37.3685  sourcesink
# 11    N1  147.3490  sourcesink
# 12    N1  159.6335  sourcesink
# 13    N1  200.5025  sourcesink
# 14    N1  217.4040  sourcesink
# 15    N1  462.2540  sourcesink
# 16  N102    0.0000  sourcesink
# 17  N102   82.6820  sourcesink
# 18  N102   83.3820  sourcesink
# 19  N104    0.0000  sourcesink
# 20  N104   49.6300  sourcesink
# 21  N105    0.0000  sourcesink
# 22  N105   48.8700  sourcesink
# 23  N105   48.8810  sourcesink
# 24    N2    0.0000  sourcesink
# 25    N2    2.3130  sourcesink
# 26    N2    8.5935  sourcesink
# 27    N2   11.5440  sourcesink
# 28    N2  286.5160  sourcesink
# 29  N204    0.0000  sourcesink
# 30  N204   34.4210  sourcesink
# 31  N207    0.0000  sourcesink
# 32  N207   67.9850  sourcesink
# 33  N208    0.0000  sourcesink
# 34  N208   57.4950  sourcesink
# 35    N8    0.0000  sourcesink
# 36    N8  205.1270  sourcesink
#
#                                                  name  length condition  \
# 0            Jatrabari - Int.with Z1101 (Left) (Left)     0.0       NaN
# 1       Int.with Z1101 - Signboard (Left) R111 (Left)     0.0       NaN
# 2              Signboard - Shimrail (Left)R110 (Left)     0.0       NaN
# 3                 Shimrail - Katchpur (Left)N2 (Left)     0.0       NaN
# 4               Katchpur - Madanpur (Left)N105 (Left)     0.0       NaN
# 5            Madanpur - Langalband (Left)Z1061 (Left)     0.0       NaN
# 6   Langalband - Mograpara Chowrasta (Left)Z1089 (...     0.0       NaN
# 7   Mograpara(Int.with Z1089)-Meghna Bridge West E...     0.0       NaN
# 8   Meghna Bridge Satrt-Bhaberchar (Left) z1063 (L...     0.0       NaN
# 9   Bhaberchar(Int.with Z1063)-Daudkandi Bridge (L...     0.0       NaN
# 10           Daudkandi Bridge- Daudkandi Z1062 (Left)     0.0       NaN
# 11  Feni (Int.with N104) - Feni Shahid Minar (Int....     0.0       NaN
# 12           Fazilpur Z1081 - Muhuriganj Z1032 (Left)     0.0       NaN
# 13          Baroirdala Z1086- Barabkunda Z1087 (Left)     0.0       NaN
# 14           Barabkunda Z1087-Fouzderhat Z1016 (Left)     0.0       NaN
# 15                             Whykong Z1133 - Teknaf     0.0       NaN
# 16    Mainamati-Kangsanagar (Intersection with Z1219)     0.0       NaN
# 17                                         sourcesink     0.0       NaN
# 18  Gathuria(Int. with N103)-Sarail(Kathihat, int....     0.0       NaN
# 19  Feni (Trank Road)-Feni (Mohipal Chourasta) Int...     0.0       NaN
# 20                    Maijdee(Int.with Z1429)-Sonapur     0.0       NaN
# 21  Madanpur (13th km of N1)-Nayapur, Bostail (Int...     0.0       NaN
# 22                                         sourcesink     0.0       NaN
# 23  Vogra Bypass(Int.with N3)-End of Road (Int.wit...     0.0       NaN
# 24                    Katchpur-Tarabo (Int with R201)     0.0       NaN
# 25  Tarabo(Int with R 201)-Barpa(Int. with Z1090 L...     0.0       NaN
# 26  Barpa(Int. with Z1090 LGED Road)-Bhulta (Int.w...     0.0       NaN
# 27      Bhulta (Int.with R202)-Bhulta (Int.with R203)     0.0       NaN
# 28                     Tamabil(Int.with N212)-Jaflong     0.0       NaN
# 29           Jagadishpur-Chunarughat (Int.with Z2008)     0.0       NaN
# 30          Chunarughat (Int.with Z2008)-Shaisthaganj     0.0       NaN
# 31                Mirpur-Natun Bazar (Int.with Z2008)     0.0       NaN
# 32                Moulvibazar (Int.with N208)-Sherpur     0.0       NaN
# 33                         Moulvibazar-Int.with Z2002     0.0       NaN
# 34      Royal City Chottor(int.with N210)-Int.with N2     0.0       NaN
# 35                   Jatrabari-Jurain (int.with R810)     0.0       NaN
# 36              Lebukhali (Int. with Z8806)-End of N8     0.0       NaN
#
#           lat        lon  model_type  Total Cargo  Total People  \
# 0   23.706028  90.443333  sourcesink       7880.0       11356.0
# 1   23.697361  90.461667  sourcesink       7880.0       11356.0
# 2   23.695916  90.498194  sourcesink       4831.5       11035.0
# 3   23.704583  90.518833  sourcesink       4556.5       11442.0
# 4   23.696639  90.534805  sourcesink       8205.0       14361.0
# 5   23.678166  90.555611  sourcesink       8205.0       14361.0
# 6   23.650694  90.582999  sourcesink       8205.0       14361.0
# 7   23.620472  90.607972  sourcesink       6516.5        7972.5
# 8   23.582583  90.638139  sourcesink       6516.5        7972.5
# 9   23.542583  90.674944  sourcesink       6516.5        7972.5
# 10  23.530777  90.709028  sourcesink       6516.5        7972.5
# 11  22.996389  91.399805  sourcesink       7712.5        6424.0
# 12  22.949777  91.498027  sourcesink       7712.5        6424.0
# 13  22.623472  91.655306  sourcesink       7554.0        7317.0
# 14  22.486944  91.719277  sourcesink       7554.0        7317.0
# 15  20.862917  92.298083  sourcesink        616.0        4065.0
# 16  23.478972  91.118194  sourcesink       1737.0        7362.0
# 17  24.050611  91.114667  sourcesink          NaN           NaN
# 18  24.050611  91.114667  sourcesink       2602.0        8919.0
# 19  23.009667  91.399416  sourcesink       1171.0        6628.0
# 20  22.825749  91.101444  sourcesink       1190.0        6708.0
# 21  23.690416  90.546611  sourcesink       4999.0        8112.0
# 22  23.989527  90.358222  sourcesink          NaN           NaN
# 23  23.989527  90.358222  sourcesink       5216.0        5157.0
# 24  23.705917  90.521444  sourcesink       6710.0       16598.0
# 25  23.724944  90.513417  sourcesink       6815.0       10430.0
# 26  23.763028  90.550389  sourcesink       6556.0       11192.0
# 27  23.785666  90.570583  sourcesink       6556.0       11192.0
# 28  25.157056  92.017638  sourcesink       2031.0        2712.0
# 29  24.147916  91.346611  sourcesink        366.0        1905.0
# 30  24.267388  91.477138  sourcesink        366.0        1905.0
# 31  24.294861  91.510250  sourcesink        766.0        4272.0
# 32  24.626333  91.677527  sourcesink        766.0        4272.0
# 33  24.471360  91.765556  sourcesink        964.0        6550.0
# 34  24.877555  91.875360  sourcesink       2191.0        7297.0
# 35  23.702139  90.435361  sourcesink       3677.0       17946.0
# 36  22.359722  90.318610  sourcesink        955.0        3533.0
#
#     Total Transport  Total Transport Weight  SourceSink Cargo Weight  \
# 0           19236.0                     NaN                 0.048459
# 1           19236.0                     NaN                 0.048459
# 2           15866.5                     NaN                 0.029712
# 3           15998.5                     NaN                 0.028021
# 4           22566.0                     NaN                 0.050458
# 5           22566.0                     NaN                 0.050458
# 6           22566.0                     NaN                 0.050458
# 7           14489.0                     NaN                 0.040074
# 8           14489.0                     NaN                 0.040074
# 9           14489.0                     NaN                 0.040074
# 10          14489.0                     NaN                 0.040074
# 11          14136.5                     NaN                 0.047429
# 12          14136.5                     NaN                 0.047429
# 13          14871.0                     NaN                 0.046454
# 14          14871.0                     NaN                 0.046454
# 15           4681.0                     NaN                 0.003788
# 16           9099.0                     NaN                 0.010682
# 17              NaN                     NaN                      NaN
# 18          11521.0                     NaN                 0.016001
# 19           7799.0                     NaN                 0.007201
# 20           7898.0                     NaN                 0.007318
# 21          13111.0                     NaN                 0.030742
# 22              NaN                     NaN                      NaN
# 23          10373.0                     NaN                 0.032076
# 24          23308.0                     NaN                 0.041264
# 25          17245.0                     NaN                 0.041910
# 26          17748.0                     NaN                 0.040317
# 27          17748.0                     NaN                 0.040317
# 28           4743.0                     NaN                 0.012490
# 29           2271.0                     NaN                 0.002251
# 30           2271.0                     NaN                 0.002251
# 31           5038.0                     NaN                 0.004711
# 32           5038.0                     NaN                 0.004711
# 33           7514.0                     NaN                 0.005928
# 34           9488.0                     NaN                 0.013474
# 35          21623.0                     NaN                 0.022612
# 36           4488.0                     NaN                 0.005873
#
#     SourceSink People Weight
# 0                   0.038574
# 1                   0.038574
# 2                   0.037483
# 3                   0.038866
# 4                   0.048781
# 5                   0.048781
# 6                   0.048781
# 7                   0.027081
# 8                   0.027081
# 9                   0.027081
# 10                  0.027081
# 11                  0.021821
# 12                  0.021821
# 13                  0.024854
# 14                  0.024854
# 15                  0.013808
# 16                  0.025007
# 17                       NaN
# 18                  0.030296
# 19                  0.022514
# 20                  0.022785
# 21                  0.027554
# 22                       NaN
# 23                  0.017517
# 24                  0.056379
# 25                  0.035428
# 26                  0.038016
# 27                  0.038016
# 28                  0.009212
# 29                  0.006471
# 30                  0.006471
# 31                  0.014511
# 32                  0.014511
# 33                  0.022249
# 34                  0.024786
# 35                  0.060958
# 36                  0.012001

# %%
# for each road in list roads
for road in roads:
    road_subset = df_only_sourcesink[df_only_sourcesink['road'] == road]
    road_subset = road_subset.reset_index(drop = True)
    road_last_index = road_subset.index[-1]
    road_last_row = road_subset.iloc[road_last_index]
    # add to sourcesinks
    sourcesinks.loc[len(sourcesinks.index)] = road_last_row
    # retrieve index of first row
    road_first_index = road_subset.index[0]
    # retrieve full row of first index
    road_first_row = road_subset.iloc[road_first_index]
    # add to sourcesinks
    sourcesinks.loc[len(sourcesinks.index)] = road_first_row

# %%
sourcesinks
# Out:
#     road        km        type  \
# 0     N1    0.0000  sourcesink
# 1     N1    2.4985  sourcesink
# 2     N1    5.6780  sourcesink
# 3     N1    7.9720  sourcesink
# 4     N1   10.3495  sourcesink
# 5     N1   13.9355  sourcesink
# 6     N1   17.9895  sourcesink
# 7     N1   21.8040  sourcesink
# 8     N1   27.2500  sourcesink
# 9     N1   33.6035  sourcesink
# 10    N1   37.3685  sourcesink
# 11    N1  147.3490  sourcesink
# 12    N1  159.6335  sourcesink
# 13    N1  200.5025  sourcesink
# 14    N1  217.4040  sourcesink
# 15    N1  462.2540  sourcesink
# 16  N102    0.0000  sourcesink
# 17  N102   82.6820  sourcesink
# 18  N102   83.3820  sourcesink
# 19  N104    0.0000  sourcesink
# 20    N1  462.2540  sourcesink
# 21    N1    0.0000  sourcesink
# 22  N102   83.3820  sourcesink
# 23  N102    0.0000  sourcesink
# 24  N104   49.6300  sourcesink
# 25  N104    0.0000  sourcesink
#
#                                                  name  length condition  \
# 0            Jatrabari - Int.with Z1101 (Left) (Left)     0.0       NaN
# 1       Int.with Z1101 - Signboard (Left) R111 (Left)     0.0       NaN
# 2              Signboard - Shimrail (Left)R110 (Left)     0.0       NaN
# 3                 Shimrail - Katchpur (Left)N2 (Left)     0.0       NaN
# 4               Katchpur - Madanpur (Left)N105 (Left)     0.0       NaN
# 5            Madanpur - Langalband (Left)Z1061 (Left)     0.0       NaN
# 6   Langalband - Mograpara Chowrasta (Left)Z1089 (...     0.0       NaN
# 7   Mograpara(Int.with Z1089)-Meghna Bridge West E...     0.0       NaN
# 8   Meghna Bridge Satrt-Bhaberchar (Left) z1063 (L...     0.0       NaN
# 9   Bhaberchar(Int.with Z1063)-Daudkandi Bridge (L...     0.0       NaN
# 10           Daudkandi Bridge- Daudkandi Z1062 (Left)     0.0       NaN
# 11  Feni (Int.with N104) - Feni Shahid Minar (Int....     0.0       NaN
# 12           Fazilpur Z1081 - Muhuriganj Z1032 (Left)     0.0       NaN
# 13          Baroirdala Z1086- Barabkunda Z1087 (Left)     0.0       NaN
# 14           Barabkunda Z1087-Fouzderhat Z1016 (Left)     0.0       NaN
# 15                             Whykong Z1133 - Teknaf     0.0       NaN
# 16    Mainamati-Kangsanagar (Intersection with Z1219)     0.0       NaN
# 17                                         sourcesink     0.0       NaN
# 18  Gathuria(Int. with N103)-Sarail(Kathihat, int....     0.0       NaN
# 19  Feni (Trank Road)-Feni (Mohipal Chourasta) Int...     0.0       NaN
# 20                             Whykong Z1133 - Teknaf     0.0       NaN
# 21           Jatrabari - Int.with Z1101 (Left) (Left)     0.0       NaN
# 22  Gathuria(Int. with N103)-Sarail(Kathihat, int....     0.0       NaN
# 23    Mainamati-Kangsanagar (Intersection with Z1219)     0.0       NaN
# 24                    Maijdee(Int.with Z1429)-Sonapur     0.0       NaN
# 25  Feni (Trank Road)-Feni (Mohipal Chourasta) Int...     0.0       NaN
#
#           lat        lon  model_type  Total Cargo  Total People  \
# 0   23.706028  90.443333  sourcesink       7880.0       11356.0
# 1   23.697361  90.461667  sourcesink       7880.0       11356.0
# 2   23.695916  90.498194  sourcesink       4831.5       11035.0
# 3   23.704583  90.518833  sourcesink       4556.5       11442.0
# 4   23.696639  90.534805  sourcesink       8205.0       14361.0
# 5   23.678166  90.555611  sourcesink       8205.0       14361.0
# 6   23.650694  90.582999  sourcesink       8205.0       14361.0
# 7   23.620472  90.607972  sourcesink       6516.5        7972.5
# 8   23.582583  90.638139  sourcesink       6516.5        7972.5
# 9   23.542583  90.674944  sourcesink       6516.5        7972.5
# 10  23.530777  90.709028  sourcesink       6516.5        7972.5
# 11  22.996389  91.399805  sourcesink       7712.5        6424.0
# 12  22.949777  91.498027  sourcesink       7712.5        6424.0
# 13  22.623472  91.655306  sourcesink       7554.0        7317.0
# 14  22.486944  91.719277  sourcesink       7554.0        7317.0
# 15  20.862917  92.298083  sourcesink        616.0        4065.0
# 16  23.478972  91.118194  sourcesink       1737.0        7362.0
# 17  24.050611  91.114667  sourcesink          NaN           NaN
# 18  24.050611  91.114667  sourcesink       2602.0        8919.0
# 19  23.009667  91.399416  sourcesink       1171.0        6628.0
# 20  20.862917  92.298083  sourcesink        616.0        4065.0
# 21  23.706028  90.443333  sourcesink       7880.0       11356.0
# 22  24.050611  91.114667  sourcesink       2602.0        8919.0
# 23  23.478972  91.118194  sourcesink       1737.0        7362.0
# 24  22.825749  91.101444  sourcesink       1190.0        6708.0
# 25  23.009667  91.399416  sourcesink       1171.0        6628.0
#
#     Total Transport  Total Transport Weight  SourceSink Cargo Weight  \
# 0           19236.0                     NaN                      NaN
# 1           19236.0                     NaN                      NaN
# 2           15866.5                     NaN                      NaN
# 3           15998.5                     NaN                      NaN
# 4           22566.0                     NaN                      NaN
# 5           22566.0                     NaN                      NaN
# 6           22566.0                     NaN                      NaN
# 7           14489.0                     NaN                      NaN
# 8           14489.0                     NaN                      NaN
# 9           14489.0                     NaN                      NaN
# 10          14489.0                     NaN                      NaN
# 11          14136.5                     NaN                      NaN
# 12          14136.5                     NaN                      NaN
# 13          14871.0                     NaN                      NaN
# 14          14871.0                     NaN                      NaN
# 15           4681.0                     NaN                      NaN
# 16           9099.0                     NaN                      NaN
# 17              NaN                     NaN                      NaN
# 18          11521.0                     NaN                      NaN
# 19           7799.0                     NaN                      NaN
# 20           4681.0                     NaN                 0.003788
# 21          19236.0                     NaN                 0.048459
# 22          11521.0                     NaN                 0.016001
# 23           9099.0                     NaN                 0.010682
# 24           7898.0                     NaN                 0.007318
# 25           7799.0                     NaN                 0.007201
#
#     SourceSink People Weight
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# 5                        NaN
# 6                        NaN
# 7                        NaN
# 8                        NaN
# 9                        NaN
# 10                       NaN
# 11                       NaN
# 12                       NaN
# 13                       NaN
# 14                       NaN
# 15                       NaN
# 16                       NaN
# 17                       NaN
# 18                       NaN
# 19                       NaN
# 20                  0.013808
# 21                  0.038574
# 22                  0.030296
# 23                  0.025007
# 24                  0.022785
# 25                  0.022514

# %%
# remove duplicates
duplicates = sourcesinks[sourcesinks.duplicated(subset=['road', 'km'])]
sourcesinks = sourcesinks.drop_duplicates(subset=['road', 'km'], keep='last')
sourcesinks
# Out:
#     road        km        type  \
# 1     N1    2.4985  sourcesink
# 2     N1    5.6780  sourcesink
# 3     N1    7.9720  sourcesink
# 4     N1   10.3495  sourcesink
# 5     N1   13.9355  sourcesink
# 6     N1   17.9895  sourcesink
# 7     N1   21.8040  sourcesink
# 8     N1   27.2500  sourcesink
# 9     N1   33.6035  sourcesink
# 10    N1   37.3685  sourcesink
# 11    N1  147.3490  sourcesink
# 12    N1  159.6335  sourcesink
# 13    N1  200.5025  sourcesink
# 14    N1  217.4040  sourcesink
# 17  N102   82.6820  sourcesink
# 20    N1  462.2540  sourcesink
# 21    N1    0.0000  sourcesink
# 22  N102   83.3820  sourcesink
# 23  N102    0.0000  sourcesink
# 24  N104   49.6300  sourcesink
# 25  N104    0.0000  sourcesink
#
#                                                  name  length condition  \
# 1       Int.with Z1101 - Signboard (Left) R111 (Left)     0.0       NaN
# 2              Signboard - Shimrail (Left)R110 (Left)     0.0       NaN
# 3                 Shimrail - Katchpur (Left)N2 (Left)     0.0       NaN
# 4               Katchpur - Madanpur (Left)N105 (Left)     0.0       NaN
# 5            Madanpur - Langalband (Left)Z1061 (Left)     0.0       NaN
# 6   Langalband - Mograpara Chowrasta (Left)Z1089 (...     0.0       NaN
# 7   Mograpara(Int.with Z1089)-Meghna Bridge West E...     0.0       NaN
# 8   Meghna Bridge Satrt-Bhaberchar (Left) z1063 (L...     0.0       NaN
# 9   Bhaberchar(Int.with Z1063)-Daudkandi Bridge (L...     0.0       NaN
# 10           Daudkandi Bridge- Daudkandi Z1062 (Left)     0.0       NaN
# 11  Feni (Int.with N104) - Feni Shahid Minar (Int....     0.0       NaN
# 12           Fazilpur Z1081 - Muhuriganj Z1032 (Left)     0.0       NaN
# 13          Baroirdala Z1086- Barabkunda Z1087 (Left)     0.0       NaN
# 14           Barabkunda Z1087-Fouzderhat Z1016 (Left)     0.0       NaN
# 17                                         sourcesink     0.0       NaN
# 20                             Whykong Z1133 - Teknaf     0.0       NaN
# 21           Jatrabari - Int.with Z1101 (Left) (Left)     0.0       NaN
# 22  Gathuria(Int. with N103)-Sarail(Kathihat, int....     0.0       NaN
# 23    Mainamati-Kangsanagar (Intersection with Z1219)     0.0       NaN
# 24                    Maijdee(Int.with Z1429)-Sonapur     0.0       NaN
# 25  Feni (Trank Road)-Feni (Mohipal Chourasta) Int...     0.0       NaN
#
#           lat        lon  model_type  Total Cargo  Total People  \
# 1   23.697361  90.461667  sourcesink       7880.0       11356.0
# 2   23.695916  90.498194  sourcesink       4831.5       11035.0
# 3   23.704583  90.518833  sourcesink       4556.5       11442.0
# 4   23.696639  90.534805  sourcesink       8205.0       14361.0
# 5   23.678166  90.555611  sourcesink       8205.0       14361.0
# 6   23.650694  90.582999  sourcesink       8205.0       14361.0
# 7   23.620472  90.607972  sourcesink       6516.5        7972.5
# 8   23.582583  90.638139  sourcesink       6516.5        7972.5
# 9   23.542583  90.674944  sourcesink       6516.5        7972.5
# 10  23.530777  90.709028  sourcesink       6516.5        7972.5
# 11  22.996389  91.399805  sourcesink       7712.5        6424.0
# 12  22.949777  91.498027  sourcesink       7712.5        6424.0
# 13  22.623472  91.655306  sourcesink       7554.0        7317.0
# 14  22.486944  91.719277  sourcesink       7554.0        7317.0
# 17  24.050611  91.114667  sourcesink          NaN           NaN
# 20  20.862917  92.298083  sourcesink        616.0        4065.0
# 21  23.706028  90.443333  sourcesink       7880.0       11356.0
# 22  24.050611  91.114667  sourcesink       2602.0        8919.0
# 23  23.478972  91.118194  sourcesink       1737.0        7362.0
# 24  22.825749  91.101444  sourcesink       1190.0        6708.0
# 25  23.009667  91.399416  sourcesink       1171.0        6628.0
#
#     Total Transport  Total Transport Weight  SourceSink Cargo Weight  \
# 1           19236.0                     NaN                      NaN
# 2           15866.5                     NaN                      NaN
# 3           15998.5                     NaN                      NaN
# 4           22566.0                     NaN                      NaN
# 5           22566.0                     NaN                      NaN
# 6           22566.0                     NaN                      NaN
# 7           14489.0                     NaN                      NaN
# 8           14489.0                     NaN                      NaN
# 9           14489.0                     NaN                      NaN
# 10          14489.0                     NaN                      NaN
# 11          14136.5                     NaN                      NaN
# 12          14136.5                     NaN                      NaN
# 13          14871.0                     NaN                      NaN
# 14          14871.0                     NaN                      NaN
# 17              NaN                     NaN                      NaN
# 20           4681.0                     NaN                 0.003788
# 21          19236.0                     NaN                 0.048459
# 22          11521.0                     NaN                 0.016001
# 23           9099.0                     NaN                 0.010682
# 24           7898.0                     NaN                 0.007318
# 25           7799.0                     NaN                 0.007201
#
#     SourceSink People Weight
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# 5                        NaN
# 6                        NaN
# 7                        NaN
# 8                        NaN
# 9                        NaN
# 10                       NaN
# 11                       NaN
# 12                       NaN
# 13                       NaN
# 14                       NaN
# 17                       NaN
# 20                  0.013808
# 21                  0.038574
# 22                  0.030296
# 23                  0.025007
# 24                  0.022785
# 25                  0.022514

# %%
sourcesinks['Total Transport'] = sourcesinks['Total Cargo'] + sourcesinks['Total People']
sourcesinks['Total Transport Weight'] = sourcesinks['Total Transport']/sum(sourcesinks['Total Transport'])
sourcesinks['SourceSink Cargo Weight'] = sourcesinks['Total Cargo']/sum(sourcesinks['Total Cargo'])
sourcesinks['SourceSink People Weight'] = sourcesinks['Total People']/sum(sourcesinks['Total People'])
# Out:
# /var/folders/g4/8z1prdqs5l3dj5xzv765t_sc0000gn/T/ipykernel_5279/2484827678.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sourcesinks['Total Transport'] = sourcesinks['Total Cargo'] + sourcesinks['Total People']
# /var/folders/g4/8z1prdqs5l3dj5xzv765t_sc0000gn/T/ipykernel_5279/2484827678.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sourcesinks['Total Transport Weight'] = sourcesinks['Total Transport']/sum(sourcesinks['Total Transport'])
# /var/folders/g4/8z1prdqs5l3dj5xzv765t_sc0000gn/T/ipykernel_5279/2484827678.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sourcesinks['SourceSink Cargo Weight'] = sourcesinks['Total Cargo']/sum(sourcesinks['Total Cargo'])
# /var/folders/g4/8z1prdqs5l3dj5xzv765t_sc0000gn/T/ipykernel_5279/2484827678.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sourcesinks['SourceSink People Weight'] = sourcesinks['Total People']/sum(sourcesinks['Total People'])

# %% [markdown]
# # Put sourcesinks in dataframe

# %%
# get the dataframes which needs to be merged
frames = [df, sourcesinks]
# merge dataframes into df
df = pd.concat(frames)

# %%
# sort values based on km and road name
df = df.sort_values(by=['road', 'km'])
# reset index
df = df.reset_index()

# %%
df
# Out:
#       index road        km                   type  \
# 0         1   N1    0.0000             sourcesink
# 1        21   N1    0.0000             sourcesink
# 2         2   N1    1.8000            Box Culvert
# 3         3   N1    2.4985             sourcesink
# 4         1   N1    2.4985             sourcesink
# ...     ...  ...       ...                    ...
# 1711   3636   N8  197.9790            Box Culvert
# 1712   3637   N8  198.5640            Box Culvert
# 1713   3638   N8  198.9550      RCC Girder Bridge
# 1714   3639   N8  199.2220  Baily with Steel Deck
# 1715   3641   N8  205.1270             sourcesink
#
#                                                name  length condition  \
# 0          Jatrabari - Int.with Z1101 (Left) (Left)     0.0       NaN
# 1          Jatrabari - Int.with Z1101 (Left) (Left)     0.0       NaN
# 2                                                 .    11.3         A
# 3     Int.with Z1101 - Signboard (Left) R111 (Left)     0.0       NaN
# 4     Int.with Z1101 - Signboard (Left) R111 (Left)     0.0       NaN
# ...                                             ...     ...       ...
# 1711                                              .     5.1         A
# 1712                                              .    10.1         A
# 1713                                Sheyalir Bridge    13.0         A
# 1714                                              .    21.3         C
# 1715          Lebukhali (Int. with Z8806)-End of N8     0.0       NaN
#
#             lat        lon  model_type  Total Cargo  Total People  \
# 0     23.706028  90.443333  sourcesink       7880.0       11356.0
# 1     23.706028  90.443333  sourcesink       7880.0       11356.0
# 2     23.698739  90.458861      bridge          NaN           NaN
# 3     23.697361  90.461667  sourcesink       7880.0       11356.0
# 4     23.697361  90.461667  sourcesink       7880.0       11356.0
# ...         ...        ...         ...          ...           ...
# 1711  22.420795  90.329901      bridge          NaN           NaN
# 1712  22.415863  90.328483      bridge          NaN           NaN
# 1713  22.412348  90.327632      bridge          NaN           NaN
# 1714  22.410058  90.326723      bridge          NaN           NaN
# 1715  22.359722  90.318610  sourcesink        955.0        3533.0
#
#       Total Transport  Total Transport Weight  SourceSink Cargo Weight  \
# 0             19236.0                     NaN                 0.048459
# 1             19236.0                     NaN                      NaN
# 2                 NaN                     NaN                      NaN
# 3             19236.0                     NaN                 0.048459
# 4             19236.0                     NaN                      NaN
# ...               ...                     ...                      ...
# 1711              NaN                     NaN                      NaN
# 1712              NaN                     NaN                      NaN
# 1713              NaN                     NaN                      NaN
# 1714              NaN                     NaN                      NaN
# 1715           4488.0                     NaN                 0.005873
#
#       SourceSink People Weight
# 0                     0.038574
# 1                          NaN
# 2                          NaN
# 3                     0.038574
# 4                          NaN
# ...                        ...
# 1711                       NaN
# 1712                       NaN
# 1713                       NaN
# 1714                       NaN
# 1715                  0.012001
#
# [1716 rows x 16 columns]

# %%
# drop old one with less information
df = df.drop_duplicates(subset=['road', 'km'], keep='last')

# %%
df
# Out:
#       index road        km                   type  \
# 1        21   N1    0.0000             sourcesink
# 2         2   N1    1.8000            Box Culvert
# 4         1   N1    2.4985             sourcesink
# 5         4   N1    4.9250            Box Culvert
# 7         2   N1    5.6780             sourcesink
# ...     ...  ...       ...                    ...
# 1711   3636   N8  197.9790            Box Culvert
# 1712   3637   N8  198.5640            Box Culvert
# 1713   3638   N8  198.9550      RCC Girder Bridge
# 1714   3639   N8  199.2220  Baily with Steel Deck
# 1715   3641   N8  205.1270             sourcesink
#
#                                                name  length condition  \
# 1          Jatrabari - Int.with Z1101 (Left) (Left)     0.0       NaN
# 2                                                 .    11.3         A
# 4     Int.with Z1101 - Signboard (Left) R111 (Left)     0.0       NaN
# 5                                                 .     6.6         A
# 7            Signboard - Shimrail (Left)R110 (Left)     0.0       NaN
# ...                                             ...     ...       ...
# 1711                                              .     5.1         A
# 1712                                              .    10.1         A
# 1713                                Sheyalir Bridge    13.0         A
# 1714                                              .    21.3         C
# 1715          Lebukhali (Int. with Z8806)-End of N8     0.0       NaN
#
#             lat        lon  model_type  Total Cargo  Total People  \
# 1     23.706028  90.443333  sourcesink       7880.0       11356.0
# 2     23.698739  90.458861      bridge          NaN           NaN
# 4     23.697361  90.461667  sourcesink       7880.0       11356.0
# 5     23.694664  90.487775      bridge          NaN           NaN
# 7     23.695916  90.498194  sourcesink       4831.5       11035.0
# ...         ...        ...         ...          ...           ...
# 1711  22.420795  90.329901      bridge          NaN           NaN
# 1712  22.415863  90.328483      bridge          NaN           NaN
# 1713  22.412348  90.327632      bridge          NaN           NaN
# 1714  22.410058  90.326723      bridge          NaN           NaN
# 1715  22.359722  90.318610  sourcesink        955.0        3533.0
#
#       Total Transport  Total Transport Weight  SourceSink Cargo Weight  \
# 1             19236.0                     NaN                      NaN
# 2                 NaN                     NaN                      NaN
# 4             19236.0                     NaN                      NaN
# 5                 NaN                     NaN                      NaN
# 7             15866.5                     NaN                      NaN
# ...               ...                     ...                      ...
# 1711              NaN                     NaN                      NaN
# 1712              NaN                     NaN                      NaN
# 1713              NaN                     NaN                      NaN
# 1714              NaN                     NaN                      NaN
# 1715           4488.0                     NaN                 0.005873
#
#       SourceSink People Weight
# 1                          NaN
# 2                          NaN
# 4                          NaN
# 5                          NaN
# 7                          NaN
# ...                        ...
# 1711                       NaN
# 1712                       NaN
# 1713                       NaN
# 1714                       NaN
# 1715                  0.012001
#
# [1695 rows x 16 columns]

# %%
df.to_csv('../data/bridges_cleaned_sourcesinked.csv')
