# %%
import pandas as pd
from selenium import webdriver
from io import StringIO   #in order to pass literal# strings to pandas_read_html this class is necessary.
from bs4 import BeautifulSoup
from urllib.request import urlopen

# %%
url = "../data/N1_traffic.htm"

# %%
df_traffic = pd.read_html(url)
df_traffic[4]
# Out:
#                                            0   \
# 0    List of links of N1 (  what is a link  )
# 1                                     Link no
# 2                                         NaN
# 3                                       N1-1L
# 4                                       N1-1R
# ..                                        ...
# 103                                     N1-65
# 104                                     N1-66
# 105                                     N1-67
# 106                                     N1-68
# 107                                     N1-69
#
#                                             1   \
# 0     List of links of N1 (  what is a link  )
# 1                                         Name
# 2                                          NaN
# 3     Jatrabari - Int.with Z1101 (Left) (Left)
# 4    Jatrabari - Int.with Z1101 (Left) (Right)
# ..                                         ...
# 103     Coxsbazar Link Road N110-Maricha Z1009
# 104        Maricha Z1009-Ukhia Dakbanglo Z1503
# 105       Ukhia Dakbanglo Z1503 - Gundum Z1504
# 106         GundumGundum Z1504 - Whykong Z1133
# 107                     Whykong Z1133 - Teknaf
#
#                                            2   \
# 0    List of links of N1 (  what is a link  )
# 1                              Start location
# 2                                         LRP
# 3                                        LRPS
# 4                                        LRPS
# ..                                        ...
# 103                                    LRP386
# 104                                    LRP403
# 105                                    LRP413
# 106                                    LRP420
# 107                                    LRP433
#
#                                            3   \
# 0    List of links of N1 (  what is a link  )
# 1                              Start location
# 2                                      Offset
# 3                                           0
# 4                                           0
# ..                                        ...
# 103                                       724
# 104                                       217
# 105                                       300
# 106                                       900
# 107                                       521
#
#                                            4   \
# 0    List of links of N1 (  what is a link  )
# 1                              Start location
# 2                                    Chainage
# 3                                           0
# 4                                           0
# ..                                        ...
# 103                                   381.481
# 104                                   398.205
# 105                                   408.434
# 106                                   416.044
# 107                                   428.908
#
#                                            5   \
# 0    List of links of N1 (  what is a link  )
# 1                                End location
# 2                                         LRP
# 3                                        LRPS
# 4                                        LRPS
# ..                                        ...
# 103                                    LRP403
# 104                                    LRP413
# 105                                    LRP420
# 106                                    LRP433
# 107                                    LRP467
#
#                                            6   \
# 0    List of links of N1 (  what is a link  )
# 1                                End location
# 2                                      Offset
# 3                                         822
# 4                                         822
# ..                                        ...
# 103                                       217
# 104                                       300
# 105                                       900
# 106                                       521
# 107                                       130
#
#                                            7   \
# 0    List of links of N1 (  what is a link  )
# 1                                End location
# 2                                    Chainage
# 3                                       0.822
# 4                                       0.822
# ..                                        ...
# 103                                   398.205
# 104                                   408.434
# 105                                   416.044
# 106                                   428.908
# 107                                   462.254
#
#                                            8   \
# 0    List of links of N1 (  what is a link  )
# 1                                      Length
# 2                                        (Km)
# 3                                       0.822
# 4                                       0.822
# ..                                        ...
# 103                                    16.724
# 104                                    10.229
# 105                                     7.610
# 106                                    12.864
# 107                                    33.346
#
#                                            9   ...  \
# 0    List of links of N1 (  what is a link  )  ...
# 1                                Traffic Data  ...
# 2                                 Heavy Truck  ...
# 3                                       402.0  ...
# 4                                       660.0  ...
# ..                                        ...  ...
# 103                                      24.0  ...
# 104                                      24.0  ...
# 105                                      24.0  ...
# 106                                      24.0  ...
# 107                                      24.0  ...
#
#                                            16  \
# 0    List of links of N1 (  what is a link  )
# 1                                Traffic Data
# 2                                         Car
# 3                                      1851.0
# 4                                      2608.0
# ..                                        ...
# 103                                     142.0
# 104                                     142.0
# 105                                     142.0
# 106                                     142.0
# 107                                     142.0
#
#                                            17  \
# 0    List of links of N1 (  what is a link  )
# 1                                Traffic Data
# 2                               Auto Rickshaw
# 3                                      2980.0
# 4                                      2508.0
# ..                                        ...
# 103                                    2476.0
# 104                                    2476.0
# 105                                    2476.0
# 106                                    2476.0
# 107                                    2476.0
#
#                                            18  \
# 0    List of links of N1 (  what is a link  )
# 1                                Traffic Data
# 2                                 Motor Cycle
# 3                                       398.0
# 4                                       436.0
# ..                                        ...
# 103                                     419.0
# 104                                     419.0
# 105                                     419.0
# 106                                     419.0
# 107                                     419.0
#
#                                            19  \
# 0    List of links of N1 (  what is a link  )
# 1                                Traffic Data
# 2                                    Bi-Cycle
# 3                                       232.0
# 4                                       213.0
# ..                                        ...
# 103                                      97.0
# 104                                      97.0
# 105                                      97.0
# 106                                      97.0
# 107                                      97.0
#
#                                            20  \
# 0    List of links of N1 (  what is a link  )
# 1                                Traffic Data
# 2                              Cycle Rickshaw
# 3                                       889.0
# 4                                      1088.0
# ..                                        ...
# 103                                    1042.0
# 104                                    1042.0
# 105                                    1042.0
# 106                                    1042.0
# 107                                    1042.0
#
#                                            21  \
# 0    List of links of N1 (  what is a link  )
# 1                                Traffic Data
# 2                                        Cart
# 3                                         0.0
# 4                                         0.0
# ..                                        ...
# 103                                       0.0
# 104                                       0.0
# 105                                       0.0
# 106                                       0.0
# 107                                       0.0
#
#                                            22  \
# 0    List of links of N1 (  what is a link  )
# 1                                       Total
# 2                                   Motorized
# 3                                     18236.0
# 4                                     20236.0
# ..                                        ...
# 103                                    4681.0
# 104                                    4681.0
# 105                                    4681.0
# 106                                    4681.0
# 107                                    4681.0
#
#                                            23  \
# 0    List of links of N1 (  what is a link  )
# 1                                       Total
# 2                               Non Motorized
# 3                                      1121.0
# 4                                      1301.0
# ..                                        ...
# 103                                    1139.0
# 104                                    1139.0
# 105                                    1139.0
# 106                                    1139.0
# 107                                    1139.0
#
#                                            24  \
# 0    List of links of N1 (  what is a link  )
# 1                                       Total
# 2                                  Total AADT
# 3                                     19357.0
# 4                                     21537.0
# ..                                        ...
# 103                                    5820.0
# 104                                    5820.0
# 105                                    5820.0
# 106                                    5820.0
# 107                                    5820.0
#
#                                            25
# 0    List of links of N1 (  what is a link  )
# 1                                     Traffic
# 2                                      (AADT)
# 3                                     19357.0
# 4                                     21537.0
# ..                                        ...
# 103                                    5820.0
# 104                                    5820.0
# 105                                    5820.0
# 106                                    5820.0
# 107                                    5820.0
#
# [108 rows x 26 columns]

# %%
# Read the HTML file into a Pandas dataframe
with open(url) as file:
    soup = BeautifulSoup(file, 'xml') #use BeautifulSoup to
tables = pd.read_html(StringIO(str(soup))) #use StringIO to supress future deprication warning
# Out:
# C:\Users\nelen\EPA133A-G07-A4\venv\Lib\site-packages\pandas\io\html.py:666: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   soup = BeautifulSoup(udoc, features="html5lib", from_encoding=from_encoding)

# %%
tables[3]
# Out:
#                                            0   \
# 0    List of links of N1 (  what is a link  )
# 1                                     Link no
# 2                                         NaN
# 3                                       N1-1L
# 4                                       N1-1R
# ..                                        ...
# 103                                     N1-65
# 104                                     N1-66
# 105                                     N1-67
# 106                                     N1-68
# 107                                     N1-69
#
#                                             1   \
# 0     List of links of N1 (  what is a link  )
# 1                                         Name
# 2                                          NaN
# 3     Jatrabari - Int.with Z1101 (Left) (Left)
# 4    Jatrabari - Int.with Z1101 (Left) (Right)
# ..                                         ...
# 103     Coxsbazar Link Road N110-Maricha Z1009
# 104        Maricha Z1009-Ukhia Dakbanglo Z1503
# 105       Ukhia Dakbanglo Z1503 - Gundum Z1504
# 106         GundumGundum Z1504 - Whykong Z1133
# 107                     Whykong Z1133 - Teknaf
#
#                                            2   \
# 0    List of links of N1 (  what is a link  )
# 1                              Start location
# 2                                         LRP
# 3                                        LRPS
# 4                                        LRPS
# ..                                        ...
# 103                                    LRP386
# 104                                    LRP403
# 105                                    LRP413
# 106                                    LRP420
# 107                                    LRP433
#
#                                            3   \
# 0    List of links of N1 (  what is a link  )
# 1                              Start location
# 2                                      Offset
# 3                                           0
# 4                                           0
# ..                                        ...
# 103                                       724
# 104                                       217
# 105                                       300
# 106                                       900
# 107                                       521
#
#                                            4   \
# 0    List of links of N1 (  what is a link  )
# 1                              Start location
# 2                                    Chainage
# 3                                           0
# 4                                           0
# ..                                        ...
# 103                                   381.481
# 104                                   398.205
# 105                                   408.434
# 106                                   416.044
# 107                                   428.908
#
#                                            5   \
# 0    List of links of N1 (  what is a link  )
# 1                                End location
# 2                                         LRP
# 3                                        LRPS
# 4                                        LRPS
# ..                                        ...
# 103                                    LRP403
# 104                                    LRP413
# 105                                    LRP420
# 106                                    LRP433
# 107                                    LRP467
#
#                                            6   \
# 0    List of links of N1 (  what is a link  )
# 1                                End location
# 2                                      Offset
# 3                                         822
# 4                                         822
# ..                                        ...
# 103                                       217
# 104                                       300
# 105                                       900
# 106                                       521
# 107                                       130
#
#                                            7   \
# 0    List of links of N1 (  what is a link  )
# 1                                End location
# 2                                    Chainage
# 3                                       0.822
# 4                                       0.822
# ..                                        ...
# 103                                   398.205
# 104                                   408.434
# 105                                   416.044
# 106                                   428.908
# 107                                   462.254
#
#                                            8   \
# 0    List of links of N1 (  what is a link  )
# 1                                      Length
# 2                                        (Km)
# 3                                       0.822
# 4                                       0.822
# ..                                        ...
# 103                                    16.724
# 104                                    10.229
# 105                                     7.610
# 106                                    12.864
# 107                                    33.346
#
#                                            9   ...  \
# 0    List of links of N1 (  what is a link  )  ...
# 1                                Traffic Data  ...
# 2                                 Heavy Truck  ...
# 3                                       402.0  ...
# 4                                       660.0  ...
# ..                                        ...  ...
# 103                                      24.0  ...
# 104                                      24.0  ...
# 105                                      24.0  ...
# 106                                      24.0  ...
# 107                                      24.0  ...
#
#                                            16  \
# 0    List of links of N1 (  what is a link  )
# 1                                Traffic Data
# 2                                         Car
# 3                                      1851.0
# 4                                      2608.0
# ..                                        ...
# 103                                     142.0
# 104                                     142.0
# 105                                     142.0
# 106                                     142.0
# 107                                     142.0
#
#                                            17  \
# 0    List of links of N1 (  what is a link  )
# 1                                Traffic Data
# 2                               Auto Rickshaw
# 3                                      2980.0
# 4                                      2508.0
# ..                                        ...
# 103                                    2476.0
# 104                                    2476.0
# 105                                    2476.0
# 106                                    2476.0
# 107                                    2476.0
#
#                                            18  \
# 0    List of links of N1 (  what is a link  )
# 1                                Traffic Data
# 2                                 Motor Cycle
# 3                                       398.0
# 4                                       436.0
# ..                                        ...
# 103                                     419.0
# 104                                     419.0
# 105                                     419.0
# 106                                     419.0
# 107                                     419.0
#
#                                            19  \
# 0    List of links of N1 (  what is a link  )
# 1                                Traffic Data
# 2                                    Bi-Cycle
# 3                                       232.0
# 4                                       213.0
# ..                                        ...
# 103                                      97.0
# 104                                      97.0
# 105                                      97.0
# 106                                      97.0
# 107                                      97.0
#
#                                            20  \
# 0    List of links of N1 (  what is a link  )
# 1                                Traffic Data
# 2                              Cycle Rickshaw
# 3                                       889.0
# 4                                      1088.0
# ..                                        ...
# 103                                    1042.0
# 104                                    1042.0
# 105                                    1042.0
# 106                                    1042.0
# 107                                    1042.0
#
#                                            21  \
# 0    List of links of N1 (  what is a link  )
# 1                                Traffic Data
# 2                                        Cart
# 3                                         0.0
# 4                                         0.0
# ..                                        ...
# 103                                       0.0
# 104                                       0.0
# 105                                       0.0
# 106                                       0.0
# 107                                       0.0
#
#                                            22  \
# 0    List of links of N1 (  what is a link  )
# 1                                       Total
# 2                                   Motorized
# 3                                     18236.0
# 4                                     20236.0
# ..                                        ...
# 103                                    4681.0
# 104                                    4681.0
# 105                                    4681.0
# 106                                    4681.0
# 107                                    4681.0
#
#                                            23  \
# 0    List of links of N1 (  what is a link  )
# 1                                       Total
# 2                               Non Motorized
# 3                                      1121.0
# 4                                      1301.0
# ..                                        ...
# 103                                    1139.0
# 104                                    1139.0
# 105                                    1139.0
# 106                                    1139.0
# 107                                    1139.0
#
#                                            24  \
# 0    List of links of N1 (  what is a link  )
# 1                                       Total
# 2                                  Total AADT
# 3                                     19357.0
# 4                                     21537.0
# ..                                        ...
# 103                                    5820.0
# 104                                    5820.0
# 105                                    5820.0
# 106                                    5820.0
# 107                                    5820.0
#
#                                            25
# 0    List of links of N1 (  what is a link  )
# 1                                     Traffic
# 2                                      (AADT)
# 3                                     19357.0
# 4                                     21537.0
# ..                                        ...
# 103                                    5820.0
# 104                                    5820.0
# 105                                    5820.0
# 106                                    5820.0
# 107                                    5820.0
#
# [108 rows x 26 columns]

# %%
#specify roads network to use
# roads = [N1]

# %%
# #retrieving traffic flow data for roads in network
# def retreive_flow_data(roads):
#     """Retreive html traffic flow data in an automated way"""
#     for road in roads
